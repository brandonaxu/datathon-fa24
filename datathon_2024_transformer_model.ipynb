# %% [markdown]
# # Model 1: Day-level Aggregation

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import pandas as pd
from datetime import datetime, timedelta
import tqdm

# %% [markdown]
# Loose Definitions:
#
# State 0: 0 fatalities, only demonstrations for disorder type, and no civilians targeting
#
# State 1: Political violence events and no fatalities, or demonstrations, or civilians targeted but and under 3 fatalities
#
# State 2: Political violence events and between 1 and 5 fatalities with civilians targeted, or no civilians targeted and at least 3 fatalities
#
# State 3: Over 5 fatalities

# %% [markdown]
# Features:
#
# 'event_id_cnty', 'event_date', 'year', 'time_precision',
#        'disorder_type', 'event_type', 'sub_event_type', 'actor1',
#        'assoc_actor_1', 'inter1', 'actor2', 'assoc_actor_2', 'inter2',
#        'interaction', 'civilian_targeting', 'iso', 'region', 'country',
#        'admin1', 'admin2', 'admin3', 'location', 'latitude', 'longitude',
#        'geo_precision', 'source', 'source_scale', 'notes', 'fatalities',
#        'tags', 'timestamp', 'population_best'
#
# Ones we'll use (after already having honed in on a day and a story): 'disorder_type', 'civilian_targeting', 'latitude', 'longitude', 'geo_precision', 'fatalities'
#
# Initially I was going to use 'admin1', but given the number of administrative regions, this might be too complex to aggregate over days, I'll have to think about it more...

# %% [markdown]
# TODO? Include 'notes'?

# %%
df = pd.read_csv("2023-11-01-2024-10-31.csv")
list_all_admin = []
list_all_admin.extend(df['admin1']); list_all_admin.extend(df['admin2']); list_all_admin.extend(df['admin3'])
list_all_admin = list(set(list_all_admin))

admin_encoding = { admin : i for i, admin in enumerate(list_all_admin) }

# %%
def encode_disorder_type(disorder_type):
    disorder_type = disorder_type.lower()
    if 'political violence' in disorder_type:
        return 4 / 7
    if 'strategic developments' in disorder_type:
        return 2 / 7
    return 1 / 7

def embed_day(day_df):
    # aggregate over all events that day, taking the highest severity
    disorders = sum([ encode_disorder_type(type) for type in set(day_df['disorder_type']) ])

    civilian_targeting = 0
    for dude in df['interaction']:
        if 'civilian' in dude.lower():
            civilian_targeting = 1
            break
    
    fatalities = sum(day_df['fatalities']) / 200
    return [ disorders, civilian_targeting, fatalities ]

def embed_story(story_df):
    date_format = '%Y-%m-%d'
    date_objects = None
    try:
        date_objects = [ datetime.strptime(date, date_format) for date in story_df['event_date'] ]
    except Exception:
        date_format = '%d %B %Y'
        date_objects = [ datetime.strptime(date, date_format) for date in story_df['event_date'] ]
    first_date = min(date_objects)
    last_date = max(date_objects)
    current_date = first_date

    embedding = []
    while current_date <= last_date:
        day_df = story_df[story_df['event_date'] == current_date.strftime(date_format)]
        embedding.append(embed_day(day_df))
        current_date += timedelta(days=1)
    return torch.tensor(embedding)

# %%
columns_to_check = ['actor1', 'assoc_actor_1', 'actor2', 'assoc_actor_2']
df_placeholder = df[columns_to_check].fillna("MISSING")
duplicate_groups = df_placeholder.groupby(columns_to_check).indices
sorted_stories = [ (len(value), key, index) for index, (key, value) in enumerate(duplicate_groups.items()) ]
sorted_stories = sorted(sorted_stories, reverse=True)
sorted_stories
# Out:
# [(15680,
#   ('Military Forces of Russia (2000-)', 'MISSING', 'MISSING', 'MISSING'),
#   9652),
#  (14296,
#   ('Military Forces of Israel (2022-)', 'MISSING', 'MISSING', 'MISSING'),
#   8361),
#  (14082,
#   ('Military Forces of Russia (2000-)',
#    'MISSING',
#    'Military Forces of Ukraine (2019-)',
#    'MISSING'),
#   9660),
#  (7703,
#   ('Military Forces of Russia (2000-) Air Force',
#    'MISSING',
#    'MISSING',
#    'MISSING'),
#   9769),
#  (5216,
#   ('Military Forces of Israel (2022-)',
#    'MISSING',
#    'Civilians (Palestine)',
#    'MISSING'),
#   8244),
#  (4793,
#   ('Protesters (Yemen)',
#    'Government of Yemen (2017-) Houthi',
#    'MISSING',
#    'MISSING'),
#   38396),
#  (4661,
#   ('Military Forces of Turkey (2016-)',
#    'MISSING',
#    'PKK: Kurdistan Workers Party',
#    'MISSING'),
#   10518),
#  (3538,
#   ('Military Forces of Ukraine (2019-) Air Force',
#    'Military Forces of Ukraine (2019-)',
#    'MISSING',
#    'MISSING'),
#   10752),
#  (3242,
#   ('Military Forces of Myanmar (2021-)',
#    'MISSING',
#    'Civilians (Myanmar)',
#    'MISSING'),
#   8904),
#  (2948,
#   ('Military Forces of Russia (2000-) Air Force',
#    'Military Forces of Russia (2000-)',
#    'MISSING',
#    'MISSING'),
#   9800),
#  (2863, ('Protesters (India)', 'MISSING', 'MISSING', 'MISSING'), 25009),
#  (2746,
#   ('Military Forces of Russia (2000-)',
#    'Military Forces of Russia (2000-) Air Force',
#    'Military Forces of Ukraine (2019-)',
#    'MISSING'),
#   9709),
#  (2743,
#   ('Military Forces of Ukraine (2019-)', 'MISSING', 'MISSING', 'MISSING'),
#   10637),
#  (2422,
#   ('Military Forces of Myanmar (2021-)', 'MISSING', 'MISSING', 'MISSING'),
#   9030),
#  (2366,
#   ('Military Forces of Syria (2000-)', 'MISSING', 'MISSING', 'MISSING'),
#   10253),
#  (2365,
#   ('Military Forces of Sudan (2019-)',
#    'MISSING',
#    'Rapid Support Forces',
#    'MISSING'),
#   10128),
#  (2198, ('Protesters (Mexico)', 'MISSING', 'MISSING', 'MISSING'), 28522),
#  (2184,
#   ('Unidentified Gang (Mexico)', 'MISSING', 'Civilians (Mexico)', 'MISSING'),
#   49843),
#  (2176,
#   ('Military Forces of Israel (2022-)', 'MISSING', 'Hezbollah', 'MISSING'),
#   8340),
#  (2101,
#   ('Protesters (United States)', 'MISSING', 'MISSING', 'MISSING'),
#   37412),
#  (2044,
#   ('Military Forces of Ukraine (2019-) Air Force',
#    'MISSING',
#    'MISSING',
#    'MISSING'),
#   10719),
#  (2036,
#   ('Rioters (Palestine)',
#    'MISSING',
#    'Military Forces of Israel (2022-)',
#    'MISSING'),
#   43827),
#  (2015,
#   ('Military Forces of Russia (2000-)',
#    'MISSING',
#    'Military Forces of Ukraine (2019-) Air Force',
#    'MISSING'),
#   9676),
#  (1895,
#   ('Protesters (India)', 'Labor Group (India)', 'MISSING', 'MISSING'),
#   24894),
#  (1860,
#   ('Unidentified Armed Group (Mexico)',
#    'MISSING',
#    'Civilians (Mexico)',
#    'MISSING'),
#   47984),
#  (1807,
#   ('Unidentified Gang and/or Police Militia',
#    'MISSING',
#    'Civilians (Brazil)',
#    'MISSING'),
#   50024),
#  (1805,
#   ('Protesters (Morocco)',
#    'Al Adl Wa Al Ihssane; Moroccan Commission for the Support of the Islamic Nation Causes; Muslim Group (Morocco)',
#    'MISSING',
#    'MISSING'),
#   28747),
#  (1766,
#   ('Protesters (Iran)', 'Labor Group (Iran)', 'MISSING', 'MISSING'),
#   25876),
#  (1581, ('Protesters (Germany)', 'MISSING', 'MISSING', 'MISSING'), 22018),
#  (1553,
#   ('Military Forces of Ukraine (2019-)',
#    'MISSING',
#    'Military Forces of Russia (2000-)',
#    'MISSING'),
#   10640),
#  (1522, ('Protesters (South Korea)', 'MISSING', 'MISSING', 'MISSING'), 32463),
#  (1470,
#   ('Military Forces of Russia (2000-)',
#    'MISSING',
#    'Civilians (Ukraine)',
#    'MISSING'),
#   9638),
#  (1465, ('Protesters (Pakistan)', 'MISSING', 'MISSING', 'MISSING'), 30338),
#  (1459, ('Hezbollah', 'MISSING', 'MISSING', 'MISSING'), 4676),
#  (1342,
#   ('Hamas Movement',
#    'MISSING',
#    'Military Forces of Israel (2022-)',
#    'MISSING'),
#   4560),
#  (1241, ('Protesters (Syria)', 'MISSING', 'MISSING', 'MISSING'), 33569),
#  (1211,
#   ('Hezbollah', 'MISSING', 'Military Forces of Israel (2022-)', 'MISSING'),
#   4678),
#  (1189,
#   ('Military Forces of Ukraine (2019-)',
#    'MISSING',
#    'Military Forces of Russia (2000-) Air Force',
#    'MISSING'),
#   10667),
#  (1141,
#   ('Rapid Support Forces', 'MISSING', 'Civilians (Sudan)', 'MISSING'),
#   38900),
#  (1111,
#   ('Military Forces of Israel (2022-)',
#    'MISSING',
#    'Civilians (Palestine)',
#    'Refugees/IDPs (Palestine)'),
#   8258),
#  (1084, ('Protesters (Myanmar)', 'MISSING', 'MISSING', 'MISSING'), 28968),
#  (992, ('Protesters (France)', 'MISSING', 'MISSING', 'MISSING'), 21144),
#  (956, ('Protesters (Indonesia)', 'MISSING', 'MISSING', 'MISSING'), 25678),
#  (942, ('Protesters (Spain)', 'MISSING', 'MISSING', 'MISSING'), 33114),
#  (922,
#   ('Military Forces of Brazil (2023-) Military Police',
#    'MISSING',
#    'Unidentified Gang (Brazil)',
#    'MISSING'),
#   7416),
#  (897,
#   ('Protesters (Poland)', 'Farmers (Poland)', 'MISSING', 'MISSING'),
#   31121),
#  (893,
#   ('Protesters (Germany)', 'Farmers (Germany)', 'MISSING', 'MISSING'),
#   21774),
#  (851,
#   ('Protesters (Pakistan)', 'Labor Group (Pakistan)', 'MISSING', 'MISSING'),
#   30285),
#  (848,
#   ('Military Forces of Russia (2000-) Air Force',
#    'MISSING',
#    'Civilians (Ukraine)',
#    'MISSING'),
#   9765),
#  (842,
#   ('Protesters (United States)',
#    'Students (United States)',
#    'MISSING',
#    'MISSING'),
#   37854),
#  (840,
#   ('Military Forces of Brazil (2023-) Military Police',
#    'MISSING',
#    'Unidentified Gang and/or Police Militia',
#    'MISSING'),
#   7419),
#  (831,
#   ('Protesters (India)',
#    'INC: Indian National Congress',
#    'MISSING',
#    'MISSING'),
#   24628),
#  (819,
#   ('Protesters (Mexico)', 'Labor Group (Mexico)', 'MISSING', 'MISSING'),
#   28481),
#  (819, ('Protesters (Israel)', 'MISSING', 'MISSING', 'MISSING'), 26269),
#  (806,
#   ('Al Shabaab', 'MISSING', 'Military Forces of Somalia (2022-)', 'MISSING'),
#   896),
#  (792,
#   ('Protesters (South Korea)',
#    'KCTU: Korean Confederation of Trade Unions; Labor Group (South Korea)',
#    'MISSING',
#    'MISSING'),
#   32362),
#  (787,
#   ('Military Forces of Ukraine (2019-)',
#    'MISSING',
#    'Military Forces of Russia (2000-) 1st Donetsk Army Corps',
#    'MISSING'),
#   10662),
#  (775, ('Protesters (Iran)', 'MISSING', 'MISSING', 'MISSING'), 25885),
#  (769,
#   ('Military Forces of Turkey (2016-)', 'MISSING', 'MISSING', 'MISSING'),
#   10504),
#  (752,
#   ('Protesters (China)', 'Labor Group (China)', 'MISSING', 'MISSING'),
#   19182),
#  (739, ('Protesters (Japan)', 'MISSING', 'MISSING', 'MISSING'), 27508),
#  (731,
#   ('Military Forces of Russia (2000-) Air Force',
#    'MISSING',
#    'Military Forces of Ukraine (2019-)',
#    'MISSING'),
#   9776),
#  (699,
#   ('Unidentified Armed Group (Brazil)',
#    'MISSING',
#    'Civilians (Brazil)',
#    'MISSING'),
#   46375),
#  (685, ('Protesters (Venezuela)', 'MISSING', 'MISSING', 'MISSING'), 38248),
#  (676,
#   ('Military Forces of Russia (2000-) Air Force',
#    'Military Forces of Russia (2000-)',
#    'Military Forces of Ukraine (2019-)',
#    'MISSING'),
#   9805),
#  (664,
#   ('Unidentified Armed Group (Brazil)',
#    'MISSING',
#    'Unidentified Armed Group (Brazil)',
#    'MISSING'),
#   46420),
#  (636, ('Protesters (Turkey)', 'MISSING', 'MISSING', 'MISSING'), 34859),
#  (608,
#   ('Islamic State West Africa Province (ISWAP) and/or Boko Haram - Jamaatu Ahli is-Sunnah lid-Dawati wal-Jihad',
#    'MISSING',
#    'Civilians (Cameroon)',
#    'MISSING'),
#   5030),
#  (606, ('Protesters (India)', 'Farmers (India)', 'MISSING', 'MISSING'), 24088),
#  (600,
#   ('Unidentified Gang (Brazil)', 'MISSING', 'Civilians (Brazil)', 'MISSING'),
#   49632),
#  (588,
#   ('Protesters (Pakistan)',
#    'PTI: Pakistan Tehreek-i-Insaf',
#    'MISSING',
#    'MISSING'),
#   30411),
#  (582, ('Protesters (Colombia)', 'MISSING', 'MISSING', 'MISSING'), 19344),
#  (581,
#   ('Protesters (India)', 'BJP: Bharatiya Janata Party', 'MISSING', 'MISSING'),
#   23247),
#  (579,
#   ('Unidentified Armed Group (Palestine)',
#    'MISSING',
#    'Military Forces of Israel (2022-)',
#    'MISSING'),
#   48529),
#  (575,
#   ('Military Forces of Israel (2022-)',
#    'MISSING',
#    'Civilians (Lebanon)',
#    'MISSING'),
#   8181),
#  (565,
#   ('Military Forces of Israel (2022-)',
#    'MISSING',
#    'Hamas Movement',
#    'MISSING'),
#   8313),
#  (556,
#   ('PKK: Kurdistan Workers Party',
#    'MISSING',
#    'Military Forces of Turkey (2016-)',
#    'MISSING'),
#   12414),
#  (545,
#   ('Unidentified Armed Group (Colombia)',
#    'MISSING',
#    'Civilians (Colombia)',
#    'MISSING'),
#   46732),
#  (534,
#   ('Protesters (Iran)', 'Muslim Group (Iran)', 'MISSING', 'MISSING'),
#   25894),
#  (520,
#   ('Rioters (Israel)',
#    'Settlers (Israel)',
#    'Civilians (Palestine)',
#    'MISSING'),
#   42467),
#  (510,
#   ('Unidentified Armed Group (Syria)',
#    'MISSING',
#    'Civilians (Syria)',
#    'MISSING'),
#   49070),
#  (507, ('Protesters (Kenya)', 'MISSING', 'MISSING', 'MISSING'), 27813),
#  (506,
#   ('Protesters (Morocco)',
#    'Al Adl Wa Al Ihssane; Muslim Group (Morocco); Moroccan Commission for the Support of the Islamic Nation Causes',
#    'MISSING',
#    'MISSING'),
#   28756),
#  (501,
#   ('Protesters (India)', 'Students (India)', 'MISSING', 'MISSING'),
#   25250),
#  (500,
#   ('Unidentified Gang and/or Police Militia',
#    'MISSING',
#    'Unidentified Gang (Brazil)',
#    'MISSING'),
#   50067),
#  (491,
#   ('Protesters (France)',
#    'Farmers (France); FNSEA: National Federation of Farmers Unions; JA: Young Farmers',
#    'MISSING',
#    'MISSING'),
#   20862),
#  (480,
#   ('Military Forces of Ethiopia (2018-)',
#    'MISSING',
#    'Fano Youth Militia',
#    'MISSING'),
#   7772),
#  (468, ('Protesters (South Africa)', 'MISSING', 'MISSING', 'MISSING'), 31945),
#  (467,
#   ('Protesters (Indonesia)', 'Students (Indonesia)', 'MISSING', 'MISSING'),
#   25761),
#  (449,
#   ('Opposition Rebels (Syria)',
#    'MISSING',
#    'Military Forces of Syria (2000-)',
#    'MISSING'),
#   12123),
#  (447, ('Protesters (Peru)', 'MISSING', 'MISSING', 'MISSING'), 30915),
#  (445, ('Protesters (Italy)', 'MISSING', 'MISSING', 'MISSING'), 27051),
#  (424, ('Protesters (Nepal)', 'MISSING', 'MISSING', 'MISSING'), 29210),
#  (407,
#   ('Military Forces of Ethiopia (2018-)',
#    'MISSING',
#    'OLF-OLA: Oromo Liberation Army-Oromo Liberation Front',
#    'MISSING'),
#   7777),
#  (399,
#   ('Civilians (Myanmar)', 'Refugees/IDPs (Myanmar)', 'MISSING', 'MISSING'),
#   2720),
#  (393,
#   ('Protesters (Sweden)',
#    'FFF: Fridays for Future; Students (Sweden)',
#    'MISSING',
#    'MISSING'),
#   33407),
#  (387,
#   ('Protesters (Yemen)',
#    'Government of Yemen (2017-) Houthi; Women (Yemen)',
#    'MISSING',
#    'MISSING'),
#   38439),
#  (385, ('Protesters (Canada)', 'MISSING', 'MISSING', 'MISSING'), 18841),
#  (376,
#   ('Military Forces of Russia (2000-) Air Force',
#    'Military Forces of Russia (2000-)',
#    'Civilians (Ukraine)',
#    'MISSING'),
#   9797),
#  (367, ('Protesters (Australia)', 'MISSING', 'MISSING', 'MISSING'), 17406),
#  (362,
#   ('QSD: Syrian Democratic Forces', 'MISSING', 'Civilians (Syria)', 'MISSING'),
#   38643),
#  (361, ('Protesters (Ukraine)', 'MISSING', 'MISSING', 'MISSING'), 35052),
#  (360,
#   ('ULA/AA: United League of Arakan/Arakan Army',
#    'MISSING',
#    'Military Forces of Myanmar (2021-)',
#    'MISSING'),
#   45986),
#  (359,
#   ('Protesters (Indonesia)', 'Labor Group (Indonesia)', 'MISSING', 'MISSING'),
#   25651),
#  (356,
#   ('Rapid Support Forces',
#    'MISSING',
#    'Military Forces of Sudan (2019-)',
#    'MISSING'),
#   38967),
#  (356, ('Protesters (Kazakhstan)', 'MISSING', 'MISSING', 'MISSING'), 27665),
#  (356,
#   ('Protesters (Bahrain)',
#    'February 14 Youth Coalition',
#    'MISSING',
#    'MISSING'),
#   17598),
#  (349,
#   ('Military Forces of the United States (2021-)',
#    'MISSING',
#    'Military Forces of Yemen (2017-) Houthi',
#    'MISSING'),
#   11279),
#  (348, ('Protesters (Spain)', 'Farmers (Spain)', 'MISSING', 'MISSING'), 32943),
#  (348,
#   ('Military Forces of Turkey (2016-)',
#    'MISSING',
#    'Civilians (International)',
#    'Refugees/IDPs (International)'),
#   10474),
#  (346,
#   ('Military Forces of Ukraine (2019-)',
#    'MISSING',
#    'Military Forces of Russia (2000-) 1st Donetsk Army Corps',
#    'Civilians (Ukraine)'),
#   10657),
#  (343,
#   ('Protesters (Bolivia)', 'Labor Group (Bolivia)', 'MISSING', 'MISSING'),
#   18201),
#  (335,
#   ('Protesters (India)', 'Teachers (India)', 'MISSING', 'MISSING'),
#   25336),
#  (333, ('Rioters (Israel)', 'Settlers (Israel)', 'MISSING', 'MISSING'), 42473),
#  (327, ('Protesters (Brazil)', 'MISSING', 'MISSING', 'MISSING'), 18397),
#  (325,
#   ('Protesters (India)',
#    'Meitei Ethnic Group (India); MP: Women Torch Bearers; Women (India)',
#    'MISSING',
#    'MISSING'),
#   25051),
#  (324, ('Protesters (Argentina)', 'MISSING', 'MISSING', 'MISSING'), 17034),
#  (312,
#   ('Military Forces of Russia (2000-) Air Force',
#    'Military Forces of Russia (2000-)',
#    'Military Forces of Ukraine (2019-)',
#    'Military Forces of Ukraine (2019-) Marines; Military Forces of Ukraine (2019-) National Guard; Military Forces of Ukraine (2019-) Territorial Defense Forces'),
#   9808),
#  (311,
#   ('Unidentified Gang (Brazil)',
#    'MISSING',
#    'Unidentified Gang (Brazil)',
#    'MISSING'),
#   49654),
#  (311,
#   ('Fano Youth Militia',
#    'MISSING',
#    'Military Forces of Ethiopia (2018-)',
#    'MISSING'),
#   3567),
#  (307,
#   ('Protesters (France)',
#    'CGT: General Confederation of Labor (France); Labor Group (France)',
#    'MISSING',
#    'MISSING'),
#   20618),
#  (307,
#   ('Military Forces of Yemen (2017-) Houthi', 'MISSING', 'MISSING', 'MISSING'),
#   10955),
#  (307,
#   ('JNIM: Group for Support of Islam and Muslims',
#    'MISSING',
#    'Civilians (Burkina Faso)',
#    'MISSING'),
#   5368),
#  (302,
#   ('Protesters (South Korea)',
#    'Labor Group (South Korea)',
#    'MISSING',
#    'MISSING'),
#   32426),
#  (301, ('Protesters (Nigeria)', 'MISSING', 'MISSING', 'MISSING'), 29629),
#  (300,
#   ('Protesters (Mexico)',
#    'Judges (Mexico); Labor Group (Mexico)',
#    'MISSING',
#    'MISSING'),
#   28463),
#  (299, ('Rapid Support Forces', 'MISSING', 'MISSING', 'MISSING'), 38955),
#  (298,
#   ('Military Forces of Ukraine (2019-)',
#    'MISSING',
#    'Military Forces of Russia (2000-)',
#    'Military Forces of Russia (2000-) Air Force'),
#   10643),
#  (297,
#   ('Ambazonian Separatists (Cameroon)',
#    'MISSING',
#    'Civilians (Cameroon)',
#    'MISSING'),
#   1191),
#  (295,
#   ('Protesters (India)', 'Health Workers (India)', 'MISSING', 'MISSING'),
#   24505),
#  (292,
#   ('Police Forces of Iraq (2022-)', 'MISSING', 'Smugglers (Iraq)', 'MISSING'),
#   14843),
#  (291,
#   ('Military Forces of Turkey (2016-)',
#    'Opposition Rebels (Syria)',
#    'MISSING',
#    'MISSING'),
#   10549),
#  (287, ('Protesters (Iraq)', 'MISSING', 'MISSING', 'MISSING'), 25990),
#  (287,
#   ('Protesters (India)', 'Hindu Group (India)', 'MISSING', 'MISSING'),
#   24573),
#  (286, ('Protesters (Mexico)', 'Women (Mexico)', 'MISSING', 'MISSING'), 28620),
#  (286,
#   ('Protesters (India)', 'AAP: Aam Aadmi Party', 'MISSING', 'MISSING'),
#   22647),
#  (285,
#   ('Protesters (Iraq)', 'Labor Group (Iraq)', 'MISSING', 'MISSING'),
#   25976),
#  (285,
#   ('Protesters (France)', 'Labor Group (France)', 'MISSING', 'MISSING'),
#   21094),
#  (283,
#   ('Protesters (Mexico)', 'Students (Mexico)', 'MISSING', 'MISSING'),
#   28597),
#  (281,
#   ('JNIM: Group for Support of Islam and Muslims',
#    'MISSING',
#    'VDP: Volunteer for Defense of Homeland',
#    'MISSING'),
#   5490),
#  (281,
#   ('Global Coalition Against Daesh', 'MISSING', 'MISSING', 'MISSING'),
#   3795),
#  (277,
#   ('Military Forces of Ukraine (2019-) Air Force',
#    'MISSING',
#    'Military Forces of Russia (2000-)',
#    'MISSING'),
#   10725),
#  (276,
#   ('Protesters (Kazakhstan)',
#    'Labor Group (Kazakhstan)',
#    'MISSING',
#    'MISSING'),
#   27662),
#  (274,
#   ('Military Forces of Sudan (2019-)', 'MISSING', 'MISSING', 'MISSING'),
#   10112),
#  (273, ('Protesters (Bolivia)', 'MISSING', 'MISSING', 'MISSING'), 18219),
#  (273,
#   ('PIJ: Palestinian Islamic Jihad',
#    'MISSING',
#    'Military Forces of Israel (2022-)',
#    'MISSING'),
#   12383),
#  (272,
#   ('Protesters (Spain)', 'Labor Group (Spain)', 'MISSING', 'MISSING'),
#   33090),
#  (268,
#   ('Unidentified Armed Group (Haiti)', 'MISSING', 'MISSING', 'MISSING'),
#   47197),
#  (268,
#   ('Protesters (Pakistan)', 'JI: Jamaat-e-Islami', 'MISSING', 'MISSING'),
#   30180),
#  (267,
#   ('Unidentified Armed Group (Myanmar)',
#    'MISSING',
#    'Civilians (Myanmar)',
#    'MISSING'),
#   48170),
#  (267,
#   ('JNIM: Group for Support of Islam and Muslims',
#    'MISSING',
#    'Civilians (Mali)',
#    'MISSING'),
#   5402),
#  (266,
#   ('Protesters (India)',
#    'BKU: Bharatiya Kisan Union; Farmers (India)',
#    'MISSING',
#    'MISSING'),
#   23471),
#  (265, ('Patriot Front', 'MISSING', 'MISSING', 'MISSING'), 12578),
#  (263,
#   ('Military Forces of Burkina Faso (2022-)',
#    'MISSING',
#    'JNIM: Group for Support of Islam and Muslims',
#    'MISSING'),
#   7452),
#  (262,
#   ('Protesters (Venezuela)',
#    'MUD: Democratic Unity Roundtable',
#    'MISSING',
#    'MISSING'),
#   38252),
#  (259,
#   ('Unidentified Armed Group (Nigeria)',
#    'MISSING',
#    'Civilians (Nigeria)',
#    'MISSING'),
#   48352),
#  (259,
#   ('Protesters (India)',
#    'Health Workers (India); Students (India)',
#    'MISSING',
#    'MISSING'),
#   24549),
#  (257,
#   ('Protesters (Peru)', 'Labor Group (Peru)', 'MISSING', 'MISSING'),
#   30896),
#  (257,
#   ('Protesters (Bangladesh)',
#    'Labor Group (Bangladesh)',
#    'MISSING',
#    'MISSING'),
#   17831),
#  (255,
#   ('Protesters (United Kingdom)', 'MISSING', 'MISSING', 'MISSING'),
#   35198),
#  (255,
#   ('Protesters (Turkey)',
#    'IHD: Human Rights Association',
#    'MISSING',
#    'MISSING'),
#   34724),
#  (253,
#   ('Protesters (Morocco)',
#    'Moroccan Front for Supporting Palestine and Against Normalisation',
#    'MISSING',
#    'MISSING'),
#   28865),
#  (252,
#   ('Protesters (Yemen)',
#    'Government of Yemen (2017-) Houthi; Military Forces of Yemen (2017-) Houthi; Police Forces of Yemen (2017-) Houthi',
#    'MISSING',
#    'MISSING'),
#   38415),
#  (252,
#   ('Protesters (Pakistan)', 'Farmers (Pakistan)', 'MISSING', 'MISSING'),
#   29996),
#  (250, ('Protesters (Panama)', 'MISSING', 'MISSING', 'MISSING'), 30661),
#  (250, ('Protesters (Chile)', 'MISSING', 'MISSING', 'MISSING'), 19122),
#  (249,
#   ('Al Aqsa Martyrs Brigade',
#    'MISSING',
#    'Military Forces of Israel (2022-)',
#    'MISSING'),
#   583),
#  (248,
#   ('Military Forces of Yemen (2017-) Houthi',
#    'MISSING',
#    'Civilians (Yemen)',
#    'MISSING'),
#   10928),
#  (246, ('Protesters (Jordan)', 'MISSING', 'MISSING', 'MISSING'), 27639),
#  (244, ('Protesters (Morocco)', 'MISSING', 'MISSING', 'MISSING'), 28858),
#  (242,
#   ('Rioters (Palestine)',
#    'Refugees/IDPs (Palestine)',
#    'Military Forces of Israel (2022-)',
#    'MISSING'),
#   43852),
#  (242, ('Protesters (Russia)', 'MISSING', 'MISSING', 'MISSING'), 31503),
#  (241,
#   ('Military Forces of Russia (2000-)',
#    'MISSING',
#    'Islamic State in Iraq and the Levant (ISIL)',
#    'MISSING'),
#   9650),
#  (237,
#   ('Settlers (Israel)', 'MISSING', 'Civilians (Palestine)', 'MISSING'),
#   45191),
#  (237,
#   ('Protesters (Greece)', 'Farmers (Greece)', 'MISSING', 'MISSING'),
#   22246),
#  (235,
#   ('Dahalo Militia', 'MISSING', 'Civilians (Madagascar)', 'MISSING'),
#   2856),
#  (234,
#   ('Tribal and Clan Forces',
#    'MISSING',
#    'QSD: Syrian Democratic Forces',
#    'MISSING'),
#   45901),
#  (234, ('Protesters (Taiwan)', 'MISSING', 'MISSING', 'MISSING'), 33739),
#  (234,
#   ('Protesters (Bangladesh)', 'Students (Bangladesh)', 'MISSING', 'MISSING'),
#   17884),
#  (232,
#   ('Military Forces of Ukraine (2019-) Air Force',
#    'MISSING',
#    'Civilians (Russia)',
#    'MISSING'),
#   10713),
#  (230,
#   ('Protesters (Yemen)',
#    'Government of Yemen (2017-) Houthi; Police Forces of Yemen (2017-) Houthi',
#    'MISSING',
#    'MISSING'),
#   38422),
#  (230,
#   ('Protesters (Pakistan)', 'Journalists (Pakistan)', 'MISSING', 'MISSING'),
#   30254),
#  (230,
#   ('Military Forces of Syria (2000-)',
#    'MISSING',
#    'Civilians (Syria)',
#    'MISSING'),
#   10215),
#  (228,
#   ('Protesters (Colombia)', 'Labor Group (Colombia)', 'MISSING', 'MISSING'),
#   19326),
#  (225,
#   ('Islamic State in Iraq and the Levant (ISIL)',
#    'MISSING',
#    'QSD: Syrian Democratic Forces',
#    'MISSING'),
#   5261),
#  (224,
#   ('Protesters (United States)',
#    'Labor Group (United States)',
#    'MISSING',
#    'MISSING'),
#   37201),
#  (224, ('Protesters (Paraguay)', 'MISSING', 'MISSING', 'MISSING'), 30791),
#  (222, ('Protesters (Palestine)', 'MISSING', 'MISSING', 'MISSING'), 30583),
#  (221,
#   ('Al Fath Al Mubeen Operation Room',
#    'MISSING',
#    'Military Forces of Syria (2000-)',
#    'MISSING'),
#   663),
#  (219,
#   ('Protesters (Poland)', 'Labor Group (Poland)', 'MISSING', 'MISSING'),
#   31174),
#  (219,
#   ('Protesters (Bolivia)',
#    'Farmers (Bolivia); MAS-IPSP: Movement for Socialism-Political Instrument for the Sovereignty of the Peoples',
#    'MISSING',
#    'MISSING'),
#   18166),
#  (219,
#   ('Military Forces of Turkey (2016-)',
#    'MISSING',
#    'QSD: Syrian Democratic Forces',
#    'MISSING'),
#   10524),
#  (218,
#   ('TTP: Tehreek-i-Taliban Pakistan',
#    'MISSING',
#    'Police Forces of Pakistan (2022-)',
#    'MISSING'),
#   45696),
#  (218,
#   ('Protesters (Turkey)',
#    "DEM: Peoples' Equality and Democracy Party",
#    'MISSING',
#    'MISSING'),
#   34320),
#  (218,
#   ('Protesters (Mexico)', 'Teachers (Mexico)', 'MISSING', 'MISSING'),
#   28611),
#  (217,
#   ('Protesters (Turkey)', 'Muslim Group (Turkey)', 'MISSING', 'MISSING'),
#   34870),
#  (215, ('Protesters (Bulgaria)', 'MISSING', 'MISSING', 'MISSING'), 18475),
#  (214,
#   ('Protesters (South Korea)',
#    'DPK: Democratic Party of Korea; Government of South Korea (2022-)',
#    'MISSING',
#    'MISSING'),
#   32112),
#  (213,
#   ('Protesters (India)',
#    'Farmers (India); KMM: Kisan Mazdoor Morcha; Labor Group (India); SKM (Non-political): United Farmers Front (Non-political)',
#    'MISSING',
#    'MISSING'),
#   24157),
#  (213,
#   ('PKK-YJA STAR: Kurdistan Workers Party-YJA STAR',
#    'MISSING',
#    'Military Forces of Turkey (2016-)',
#    'MISSING'),
#   12402),
#  (205,
#   ('Rioters (Israel)',
#    'Settlers (Israel)',
#    'Civilians (Palestine)',
#    'Farmers (Palestine)'),
#   42458),
#  (205,
#   ('Protesters (India)',
#    "AASU: All Assam Students' Union; Students (India)",
#    'MISSING',
#    'MISSING'),
#   22747),
#  (204,
#   ('Unidentified Armed Group (Mexico)',
#    'MISSING',
#    'Civilians (Mexico)',
#    'Labor Group (Mexico)'),
#   47969),
#  (201, ('Protesters (Iran)', 'Students (Iran)', 'MISSING', 'MISSING'), 25904),
#  (201,
#   ('Military Forces of Myanmar (2021-)',
#    'MISSING',
#    'Unidentified Anti-Coup Armed Group',
#    'MISSING'),
#   9184),
#  (201,
#   ('Al Shabaab',
#    'MISSING',
#    'ATMIS: African Union Transition Mission in Somalia (2022-) (Uganda)',
#    'MISSING'),
#   799),
#  (200,
#   ('Military Forces of Ukraine (2019-)',
#    'MISSING',
#    'Civilians (Russia)',
#    'MISSING'),
#   10627),
#  (197,
#   ('Protesters (India)',
#    'BJP: Bharatiya Janata Party; Government of India (2014-)',
#    'MISSING',
#    'MISSING'),
#   23358),
#  (197,
#   ('Military Forces of Israel (2022-)',
#    'MISSING',
#    'Civilians (Palestine)',
#    'Farmers (Palestine)'),
#   8208),
#  (196,
#   ('Unidentified Armed Group (Trinidad and Tobago)',
#    'MISSING',
#    'Civilians (Trinidad and Tobago)',
#    'MISSING'),
#   49235),
#  (196, ('Civilians (Haiti)', 'MISSING', 'MISSING', 'MISSING'), 2621),
#  (194,
#   ('Unidentified Anti-Coup Armed Group',
#    'MISSING',
#    'Military Forces of Myanmar (2021-)',
#    'MISSING'),
#   46090),
#  (194,
#   ('Protesters (Romania)', 'Labor Group (Romania)', 'MISSING', 'MISSING'),
#   31448),
#  (194,
#   ('Military Forces of Ukraine (2019-) Air Force',
#    'Military Forces of Ukraine (2019-)',
#    'Civilians (Russia)',
#    'MISSING'),
#   10747),
#  (193,
#   ('Rioters (Palestine)',
#    'MISSING',
#    'Civilians (Israel)',
#    'Settlers (Israel)'),
#   43821),
#  (191, ('Protesters (Denmark)', 'MISSING', 'MISSING', 'MISSING'), 19718),
#  (191,
#   ('Protesters (Brazil)', 'Labor Group (Brazil)', 'MISSING', 'MISSING'),
#   18380),
#  (191,
#   ('National Resistance Front',
#    'MISSING',
#    'Military Forces of Afghanistan (2021-)',
#    'MISSING'),
#   11777),
#  (190,
#   ('Unidentified Armed Group (Mexico)',
#    'MISSING',
#    'Police Forces of Mexico (2018-)',
#    'MISSING'),
#   48080),
#  (189,
#   ('Rioters (Kenya)',
#    'Vigilante Group (Kenya)',
#    'Civilians (Kenya)',
#    'MISSING'),
#   42802),
#  (189,
#   ('Protesters (Venezuela)', 'Labor Group (Venezuela)', 'MISSING', 'MISSING'),
#   38217),
#  (188,
#   ('Protesters (Argentina)', 'Labor Group (Argentina)', 'MISSING', 'MISSING'),
#   16986),
#  (186,
#   ('Rioters (Brazil)',
#    'Vigilante Group (Brazil)',
#    'Civilians (Brazil)',
#    'MISSING'),
#   39889),
#  (186,
#   ('Protesters (France)',
#    'SNES-FSU: National Union of Secondary Education; Teachers (France)',
#    'MISSING',
#    'MISSING'),
#   21208),
#  (185,
#   ('Protesters (Pakistan)', 'Teachers (Pakistan)', 'MISSING', 'MISSING'),
#   30491),
#  (185,
#   ('ADF: Allied Democratic Forces',
#    'MISSING',
#    'Civilians (Democratic Republic of Congo)',
#    'MISSING'),
#   283),
#  (184,
#   ('Military Forces of Myanmar (2021-)',
#    'MISSING',
#    'ULA/AA: United League of Arakan/Arakan Army',
#    'MISSING'),
#   9177),
#  (183,
#   ('Unidentified Armed Group (Mexico)',
#    'MISSING',
#    'Civilians (Mexico)',
#    'Women (Mexico)'),
#   48047),
#  (182,
#   ('Protesters (Italy)', 'Students (Italy)', 'MISSING', 'MISSING'),
#   27119),
#  (181, ('Protesters (Yemen)', 'MISSING', 'MISSING', 'MISSING'), 38460),
#  (180, ('Protesters (Tunisia)', 'MISSING', 'MISSING', 'MISSING'), 33925),
#  (180, ('Protesters (India)', 'Women (India)', 'MISSING', 'MISSING'), 25379),
#  (180, ('Protesters (Honduras)', 'MISSING', 'MISSING', 'MISSING'), 22537),
#  (177,
#   ('Unidentified Armed Group (Honduras)',
#    'MISSING',
#    'Civilians (Honduras)',
#    'MISSING'),
#   47225),
#  (177, ('Rioters (Brazil)', 'MISSING', 'MISSING', 'MISSING'), 39868),
#  (177,
#   ('Protesters (Italy)', 'Labor Group (Italy)', 'MISSING', 'MISSING'),
#   27002),
#  (174,
#   ('Protesters (Turkey)', 'Labor Group (Turkey)', 'MISSING', 'MISSING'),
#   34800),
#  (174,
#   ('Protesters (Canada)', 'Students (Canada)', 'MISSING', 'MISSING'),
#   18902),
#  (174,
#   ('Ambazonian Separatists (Cameroon)',
#    'Ambazonian Separatists (Cameroon) Restoration Forces',
#    'Civilians (Cameroon)',
#    'MISSING'),
#   1121),
#  (173, ('Rioters (South Africa)', 'MISSING', 'MISSING', 'MISSING'), 44322),
#  (173, ('Protesters (Bahrain)', 'MISSING', 'MISSING', 'MISSING'), 17611),
#  (172, ('Protesters (Sweden)', 'MISSING', 'MISSING', 'MISSING'), 33439),
#  (172,
#   ('Protesters (Iran)', 'Health Workers (Iran)', 'MISSING', 'MISSING'),
#   25865),
#  (171,
#   ('Protesters (Kenya)',
#    'KUPPET: Kenya Union of Post Primary Education Teachers; Teachers (Kenya)',
#    'MISSING',
#    'MISSING'),
#   27779),
#  (171,
#   ('Protesters (Colombia)',
#    'ACC: Colombian Association of Truck Drivers; Labor Group (Colombia)',
#    'MISSING',
#    'MISSING'),
#   19209),
#  (171, ('Protesters (Belgium)', 'MISSING', 'MISSING', 'MISSING'), 18075),
#  (168,
#   ('Protesters (India)',
#    'Government of India (2014-); INC: Indian National Congress',
#    'MISSING',
#    'MISSING'),
#   24389),
#  (167,
#   ('Protesters (India)', 'BRS: Bharat Rashtra Samithi', 'MISSING', 'MISSING'),
#   23530),
#  (166, ('Protesters (Netherlands)', 'MISSING', 'MISSING', 'MISSING'), 29354),
#  (166,
#   ('Military Forces of Myanmar (2021-)',
#    'MISSING',
#    "PSLF/TNLA: Palaung State Liberation Front/Ta'ang National Liberation Army",
#    'MISSING'),
#   9074),
#  (165, ('Protesters (Norway)', 'MISSING', 'MISSING', 'MISSING'), 29802),
#  (165,
#   ('Military Forces of Sudan (2019-)',
#    'MISSING',
#    'Civilians (Sudan)',
#    'MISSING'),
#   10094),
#  (164,
#   ('Protesters (United States)',
#    'SJP: Students for Justice in Palestine; Students (United States)',
#    'MISSING',
#    'MISSING'),
#   37801),
#  (163,
#   ('Military Forces of Turkey (2016-)',
#    'MISSING',
#    'YPG: Peoples Protection Units',
#    'MISSING'),
#   10532),
#  (161,
#   ('Protesters (Nepal)', 'Labor Group (Nepal)', 'MISSING', 'MISSING'),
#   29199),
#  (160,
#   ('Protesters (United States)',
#    'DEM: Democratic Party; Government of the United States (2021-)',
#    'MISSING',
#    'MISSING'),
#   36300),
#  (159,
#   ('Unidentified Military Forces',
#    'MISSING',
#    'Civilians (Ukraine)',
#    'MISSING'),
#   50104),
#  (159,
#   ('Protesters (United States)',
#    'Labor Group (United States); Unite Here',
#    'MISSING',
#    'MISSING'),
#   37354),
#  (159,
#   ('Military Forces of Myanmar (2021-)',
#    'Pyu Saw Htee',
#    'Civilians (Myanmar)',
#    'MISSING'),
#   9299),
#  (158,
#   ('Unidentified Gang (Mexico)',
#    'MISSING',
#    'Civilians (Mexico)',
#    'Women (Mexico)'),
#   49871),
#  (158,
#   ('Protesters (Yemen)',
#    'Government of Yemen (2017-) Houthi; Students (Yemen)',
#    'MISSING',
#    'MISSING'),
#   38427),
#  (157,
#   ("PSLF/TNLA: Palaung State Liberation Front/Ta'ang National Liberation Army",
#    'MISSING',
#    'Military Forces of Myanmar (2021-)',
#    'MISSING'),
#   12511),
#  (157,
#   ('JNIM: Group for Support of Islam and Muslims',
#    'MISSING',
#    'Military Forces of Mali (2021-)',
#    'MISSING'),
#   5452),
#  (156,
#   ('Military Forces of Mali (2021-)',
#    'Wagner Group',
#    'Civilians (Mali)',
#    'MISSING'),
#   8661),
#  (155,
#   ('Katsina Communal Militia (Nigeria)',
#    'MISSING',
#    'Civilians (Nigeria)',
#    'MISSING'),
#   6145),
#  (155, ('Hamas Movement', 'MISSING', 'MISSING', 'MISSING'), 4558),
#  (154,
#   ('Zamfara Communal Militia (Nigeria)',
#    'MISSING',
#    'Civilians (Nigeria)',
#    'MISSING'),
#   50566),
#  (154,
#   ('Rioters (Bangladesh)',
#    'BNP: Bangladesh Nationalist Party; JeI: Jamaat-e-Islami',
#    'MISSING',
#    'MISSING'),
#   39357),
#  (154, ('Protesters (Bangladesh)', 'MISSING', 'MISSING', 'MISSING'), 17865),
#  (154,
#   ('Global Coalition Against Daesh',
#    'Military Forces of the United States (2021-)',
#    'MISSING',
#    'MISSING'),
#   3818),
#  (153, ('Protesters (Iran)', 'Teachers (Iran)', 'MISSING', 'MISSING'), 25914),
#  (153,
#   ('Protesters (India)',
#    'CITU: Centre of Indian Trade Unions; Labor Group (India)',
#    'MISSING',
#    'MISSING'),
#   23699),
#  (153, ('Protesters (Armenia)', 'MISSING', 'MISSING', 'MISSING'), 17115),
#  (150,
#   ('Unidentified Armed Group (Iraq)',
#    'MISSING',
#    'Civilians (Iraq)',
#    'MISSING'),
#   47570),
#  (149,
#   ('Rioters (Mexico)',
#    'Vigilante Group (Mexico)',
#    'Civilians (Mexico)',
#    'MISSING'),
#   43176),
#  (149,
#   ('Military Forces of Somalia (2022-)', 'MISSING', 'Al Shabaab', 'MISSING'),
#   9911),
#  (148,
#   ('Unidentified Armed Group (Syria)',
#    'MISSING',
#    'QSD: Syrian Democratic Forces',
#    'MISSING'),
#   49191),
#  (148,
#   ('Rapid Support Forces',
#    'Darfur Arab Militia (Sudan)',
#    'Military Forces of Sudan (2019-)',
#    'Darfur Joint Forces/JSAMF: Joint Force of Armed Struggle Movement'),
#   38812),
#  (148,
#   ('Protesters (India)',
#    'CPI(M): Communist Party of India (Marxist)',
#    'MISSING',
#    'MISSING'),
#   23728),
#  (148,
#   ('Protesters (Honduras)', 'Labor Group (Honduras)', 'MISSING', 'MISSING'),
#   22524),
#  (148, ('Protesters (Haiti)', 'MISSING', 'MISSING', 'MISSING'), 22482),
#  (147,
#   ('Protesters (Sri Lanka)', 'Labor Group (Sri Lanka)', 'MISSING', 'MISSING'),
#   33301),
#  (146,
#   ('Rioters (India)',
#    'Vigilante Group (India)',
#    'Civilians (India)',
#    'MISSING'),
#   42092),
#  (146,
#   ('Protesters (France)',
#    'FNSEA: National Federation of Farmers Unions; JA: Young Farmers; Farmers (France)',
#    'MISSING',
#    'MISSING'),
#   20805),
#  (144,
#   ('Unidentified Armed Group (Mexico)',
#    'MISSING',
#    'Unidentified Armed Group (Mexico)',
#    'MISSING'),
#   48117),
#  (144,
#   ('Protesters (Chile)', 'Labor Group (Chile)', 'MISSING', 'MISSING'),
#   19101),
#  (144,
#   ('Military Forces of Brazil (2023-) Military Police',
#    'MISSING',
#    'CV: Red Command',
#    'MISSING'),
#   7385),
#  (143,
#   ('Unidentified Armed Group (Myanmar)', 'MISSING', 'MISSING', 'MISSING'),
#   48188),
#  (143, ('Protesters (Sri Lanka)', 'MISSING', 'MISSING', 'MISSING'), 33321),
#  (142,
#   ('Protesters (Yemen)',
#    'Government of Yemen (2017-) Houthi; Unidentified Tribal Group (Yemen)',
#    'MISSING',
#    'MISSING'),
#   38435),
#  (139,
#   ('Protesters (Sweden)',
#    "Women's Strike (Sweden); Women (Sweden)",
#    'MISSING',
#    'MISSING'),
#   33474),
#  (139,
#   ('National Police Forces', 'MISSING', 'Civilians (Syria)', 'MISSING'),
#   11753),
#  (139,
#   ('Hamas Movement',
#    'PIJ: Palestinian Islamic Jihad',
#    'Military Forces of Israel (2022-)',
#    'MISSING'),
#   4574),
#  (138,
#   ('Protesters (Turkey)',
#    "DEM: Peoples' Equality and Democracy Party; Government of Turkey (2016-)",
#    'MISSING',
#    'MISSING'),
#   34376),
#  (138,
#   ('HTS: Hayat Tahrir al Sham',
#    'MISSING',
#    'Military Forces of Syria (2000-)',
#    'MISSING'),
#   4424),
#  (137,
#   ('Protesters (India)', 'Meitei Ethnic Group (India)', 'MISSING', 'MISSING'),
#   25045),
#  (136, ('Protesters (Ireland)', 'MISSING', 'MISSING', 'MISSING'), 26104),
#  (136,
#   ('Military Forces of Yemen (2017-) Houthi',
#    'MISSING',
#    'Military Forces of Yemen (2022-) Presidential Leadership Council',
#    'MISSING'),
#   10961),
#  (135, ('Rioters (Kenya)', 'MISSING', 'MISSING', 'MISSING'), 42729),
#  (135,
#   ('Protesters (Belgium)', 'Farmers (Belgium)', 'MISSING', 'MISSING'),
#   18017),
#  (134, ('Protesters (Italy)', 'Farmers (Italy)', 'MISSING', 'MISSING'), 26806),
#  (134,
#   ('Military Forces of Madagascar (2019-) Gendarmerie',
#    'MISSING',
#    'Dahalo Militia',
#    'MISSING'),
#   8570),
#  (133,
#   ('Protesters (Yemen)',
#    'Government of Yemen (2017-) Houthi; Students (Yemen); Teachers (Yemen)',
#    'MISSING',
#    'MISSING'),
#   38429),
#  (133, ('Protesters (Finland)', 'MISSING', 'MISSING', 'MISSING'), 19940),
#  (132,
#   ('Unidentified Armed Group (Mexico)',
#    'MISSING',
#    'Police Forces of Mexico (2018-) State Police',
#    'MISSING'),
#   48101),
#  (132,
#   ('Protesters (United States)',
#    'Students (United States); Teachers (United States)',
#    'MISSING',
#    'MISSING'),
#   37940),
#  (132, ('Protesters (Japan)', 'Women (Japan)', 'MISSING', 'MISSING'), 27597),
#  (132, ('Protesters (Burkina Faso)', 'MISSING', 'MISSING', 'MISSING'), 18495),
#  (131,
#   ('Protesters (Pakistan)', 'Students (Pakistan)', 'MISSING', 'MISSING'),
#   30474),
#  (131,
#   ('Islamist Militia (Mozambique)',
#    'MISSING',
#    'Civilians (Mozambique)',
#    'MISSING'),
#   5283),
#  (130,
#   ('Protesters (United States)',
#    'Labor Group (United States); SEIU: Service Employees International Union',
#    'MISSING',
#    'MISSING'),
#   37292),
#  (130,
#   ('Protesters (Pakistan)',
#    'JUI-F: Jamiat Ulema-e-Islam-Fazl',
#    'MISSING',
#    'MISSING'),
#   30229),
#  (130,
#   ('Islamic State in Iraq and the Levant (ISIL)',
#    'MISSING',
#    'Military Forces of Syria (2000-)',
#    'MISSING'),
#   5207),
#  (129, ('Protesters (Serbia)', 'MISSING', 'MISSING', 'MISSING'), 31594),
#  (129, ('Protesters (India)', 'Lawyers (India)', 'MISSING', 'MISSING'), 24993),
#  (129,
#   ('Protesters (India)',
#    'AIADMK: All India Anna Dravida Munnetra Kazhagam',
#    'MISSING',
#    'MISSING'),
#   22808),
#  (129,
#   ('Ambazonian Separatists (Cameroon)',
#    'MISSING',
#    'Military Forces of Cameroon (1982-)',
#    'MISSING'),
#   1223),
#  (126,
#   ('Settlers (Israel)',
#    'MISSING',
#    'Civilians (Palestine)',
#    'Farmers (Palestine)'),
#   45187),
#  (126,
#   ('Rioters (South Africa)',
#    'Vigilante Group (South Africa)',
#    'Civilians (South Africa)',
#    'MISSING'),
#   44374),
#  (126, ('Protesters (Georgia)', 'MISSING', 'MISSING', 'MISSING'), 21292),
#  (126,
#   ('Government of Turkey (2016-)', 'MISSING', 'MISSING', 'MISSING'),
#   4217),
#  (125,
#   ('Protesters (Mexico)', 'Farmers (Mexico)', 'MISSING', 'MISSING'),
#   28416),
#  (124,
#   ('Rioters (Kenya)', 'MISSING', 'Police Forces of Kenya (2022-)', 'MISSING'),
#   42733),
#  (124,
#   ('Protesters (France)', 'Students (France)', 'MISSING', 'MISSING'),
#   21217),
#  (124,
#   ('Civilians (Democratic Republic of Congo)',
#    'Refugees/IDPs (Democratic Republic of Congo)',
#    'MISSING',
#    'MISSING'),
#   2611),
#  (124,
#   ('Ambazonian Separatists (Cameroon)',
#    'MISSING',
#    'Civilians (Cameroon)',
#    'Labor Group (Cameroon)'),
#   1184),
#  (123,
#   ('Protesters (Taiwan)',
#    'DPP: Democratic Progressive Party; Government of Taiwan (2016-)',
#    'MISSING',
#    'MISSING'),
#   33620),
#  (123,
#   ('Protesters (Spain)',
#    "Farmers (Spain); UdU: Union of Farmers' and Ranchers' Unions",
#    'MISSING',
#    'MISSING'),
#   32955),
#  (123,
#   ("NPA: New People's Army",
#    'MISSING',
#    'Military Forces of the Philippines (2022-)',
#    'MISSING'),
#   11612),
#  (122,
#   ('Unidentified Armed Group (Syria)',
#    'MISSING',
#    'Military Forces of Syria (2000-)',
#    'MISSING'),
#   49126),
#  (122,
#   ('Protesters (United States)',
#    'Health Workers (United States); Labor Group (United States); SEIU: Service Employees International Union',
#    'MISSING',
#    'MISSING'),
#   36844),
#  (121,
#   ('Unidentified Armed Group (Puerto Rico)',
#    'MISSING',
#    'Civilians (Puerto Rico)',
#    'MISSING'),
#   48691),
#  (121,
#   ('Rioters (Palestine)',
#    'MISSING',
#    'Police Forces of Israel (2022-)',
#    'MISSING'),
#   43833),
#  (121,
#   ('Protesters (India)',
#    'ABVP: Akhil Bharatiya Vidyarthi Parishad; Hindu Group (India); Students (India)',
#    'MISSING',
#    'MISSING'),
#   22790),
#  (120,
#   ('Protesters (South Africa)',
#    'Labor Group (South Africa)',
#    'MISSING',
#    'MISSING'),
#   31902),
#  (120,
#   ('Military Forces of Turkey (2016-) Gendarmerie',
#    'MISSING',
#    'PKK: Kurdistan Workers Party',
#    'MISSING'),
#   10582),
#  (119,
#   ('Protesters (United States)',
#    'Women (United States)',
#    'MISSING',
#    'MISSING'),
#   38040),
#  (119,
#   ('Protesters (Kenya)', 'Teachers (Kenya)', 'MISSING', 'MISSING'),
#   27851),
#  (119,
#   ('Protesters (India)',
#    'BKU: Bharatiya Kisan Union; Farmers (India); KMM: Kisan Mazdoor Morcha; Labor Group (India); SKM (Non-political): United Farmers Front (Non-political)',
#    'MISSING',
#    'MISSING'),
#   23496),
#  (117,
#   ('Protesters (India)',
#    'Farmers (India); SKM: United Farmers Front',
#    'MISSING',
#    'MISSING'),
#   24210),
#  (117,
#   ('Military Forces of Cameroon (1982-)',
#    'MISSING',
#    'Ambazonian Separatists (Cameroon)',
#    'MISSING'),
#   7496),
#  (116,
#   ('Protesters (Turkey)', 'Health Workers (Turkey)', 'MISSING', 'MISSING'),
#   34696),
#  (116,
#   ('Military Forces of Mali (2021-)',
#    'MISSING',
#    'JNIM: Group for Support of Islam and Muslims',
#    'MISSING'),
#   8616),
#  (115,
#   ('Unidentified Gang and/or Police Militia',
#    'MISSING',
#    'Civilians (Brazil)',
#    'Labor Group (Brazil)'),
#   50018),
#  (115,
#   ('Protesters (Kenya)', 'Labor Group (Kenya)', 'MISSING', 'MISSING'),
#   27795),
#  (114,
#   ('Protesters (Bangladesh)',
#    'Labor Group (Bangladesh); Students (Bangladesh)',
#    'MISSING',
#    'MISSING'),
#   17846),
#  (114,
#   ('Military Forces of the Democratic Republic of Congo (2019-)',
#    'MISSING',
#    'M23: March 23 Movement',
#    'MISSING'),
#   11165),
#  (113,
#   ('Unidentified Gang and/or Police Militia',
#    'MISSING',
#    'Civilians (Brazil)',
#    'Women (Brazil)'),
#   50044),
#  (113,
#   ('Protesters (Sweden)', 'XR: Extinction Rebellion', 'MISSING', 'MISSING'),
#   33475),
#  (113,
#   ('Protesters (Morocco)', 'Teachers (Morocco)', 'MISSING', 'MISSING'),
#   28898),
#  (112,
#   ('Protesters (United States)',
#    'IBT: International Brotherhood of Teamsters; Labor Group (United States)',
#    'MISSING',
#    'MISSING'),
#   36897),
#  (112,
#   ('Protesters (India)', 'Dalit Caste Group (India)', 'MISSING', 'MISSING'),
#   23996),
#  (111,
#   ('Rioters (India)', 'MISSING', 'Police Forces of India (2014-)', 'MISSING'),
#   41736),
#  (111,
#   ('Protesters (Spain)',
#    'CCOO: Workers Commissions; Labor Group (Spain); UGT: General Union of Workers (Spain)',
#    'MISSING',
#    'MISSING'),
#   32830),
#  (111,
#   ('Protesters (South Korea)',
#    'KCTU: Korean Confederation of Trade Unions; Teachers (South Korea)',
#    'MISSING',
#    'MISSING'),
#   32392),
#  (111,
#   ('Protesters (Indonesia)',
#    'Papuan Indigenous Group (Indonesia)',
#    'MISSING',
#    'MISSING'),
#   25737),
#  (111,
#   ('Protesters (Colombia)', 'Students (Colombia)', 'MISSING', 'MISSING'),
#   19364),
#  (111,
#   ('Military Forces of Ukraine (2019-) Marines',
#    'MISSING',
#    'Military Forces of Russia (2000-)',
#    'Military Forces of Russia (2000-) Air Force'),
#   10798),
#  (111,
#   ('MNTJP/MNDAA: Myanmar National Truth and Justice Party/Myanmar National Democratic Alliance Army',
#    'MISSING',
#    'Military Forces of Myanmar (2021-)',
#    'MISSING'),
#   6869),
#  (110,
#   ('Rioters (Colombia)',
#    'Vigilante Group (Colombia)',
#    'Civilians (Colombia)',
#    'MISSING'),
#   40173),
#  (110,
#   ('Protesters (Turkey)', 'Students (Turkey)', 'MISSING', 'MISSING'),
#   34910),
#  (110,
#   ('Protesters (Germany)', 'Labor Group (Germany)', 'MISSING', 'MISSING'),
#   21972),
#  (109,
#   ('Protesters (Yemen)',
#    'Government of Yemen (2017-) Houthi; Military Forces of Yemen (2017-) Houthi',
#    'MISSING',
#    'MISSING'),
#   38414),
#  (109,
#   ('Protesters (India)',
#    'Health Workers (India); Women (India)',
#    'MISSING',
#    'MISSING'),
#   24561),
#  (109,
#   ('Military Forces of Ukraine (2019-) Air Force',
#    'MISSING',
#    'Military Forces of Russia (2000-) 1st Donetsk Army Corps',
#    'Civilians (Ukraine)'),
#   10728),
#  (109,
#   ('BLF: Baloch Liberation Front',
#    'MISSING',
#    'Military Forces of Pakistan (2022-)',
#    'MISSING'),
#   1638),
#  (108,
#   ('Unidentified Armed Group (Jamaica)',
#    'MISSING',
#    'Civilians (Jamaica)',
#    'MISSING'),
#   47695),
#  (108, ('Protesters (Spain)', 'Women (Spain)', 'MISSING', 'MISSING'), 33192),
#  (108,
#   ('Military Forces of Cameroon (1982-)',
#    'MISSING',
#    'Civilians (Cameroon)',
#    'MISSING'),
#   7515),
#  (108,
#   ('M23: March 23 Movement',
#    'MISSING',
#    'EPLC: Awakening of Patriots for the Liberation of Congo (Wazalendo)',
#    'MISSING'),
#   6684),
#  (107,
#   ('Unidentified Armed Group (Palestine)',
#    'Rioters (Palestine)',
#    'Military Forces of Israel (2022-)',
#    'MISSING'),
#   48552),
#  (107,
#   ('Protesters (Morocco)', 'Labor Group (Morocco)', 'MISSING', 'MISSING'),
#   28833),
#  (107,
#   ('Protesters (Mexico)', 'LGBTQ+ (Mexico)', 'MISSING', 'MISSING'),
#   28474),
#  (106,
#   ('Protesters (India)', 'Muslim Group (India)', 'MISSING', 'MISSING'),
#   25087),
#  (106,
#   ('Protesters (France)',
#    'CGT: General Confederation of Labor (France); FAGE: Federation of General Student Associations; FSU: United Federation of Trade Unions; Labor Group (France); MNL: National High School Student Movement; Students (France); SUD: Democratic Unitary Solidarity; UNEF: National Union of Students of France',
#    'MISSING',
#    'MISSING'),
#   20476),
#  (106,
#   ('Protesters (France)',
#    'AFPS: France-Palestine Solidarity Association; Palestinian Group (France)',
#    'MISSING',
#    'MISSING'),
#   20035),
#  (106,
#   ('Police Forces of Israel (2022-)',
#    'MISSING',
#    'Civilians (Palestine)',
#    'MISSING'),
#   14951),
#  (106,
#   ('Military Forces of Russia (2000-)',
#    'MISSING',
#    'Unidentified Military Forces',
#    'MISSING'),
#   9698),
#  (106,
#   ('Kaduna Communal Militia (Nigeria)',
#    'MISSING',
#    'Civilians (Nigeria)',
#    'MISSING'),
#   6021),
#  (105, ('Protesters (Poland)', 'MISSING', 'MISSING', 'MISSING'), 31189),
#  (105,
#   ('Police Forces of India (2014-)',
#    'MISSING',
#    'Unidentified Armed Group (India)',
#    'MISSING'),
#   14510),
#  (105,
#   ('Islamic State West Africa Province (ISWAP)',
#    'MISSING',
#    'Military Forces of Nigeria (2023-)',
#    'MISSING'),
#   4978),
#  (104,
#   ('Unidentified Gang (Mexico)',
#    'MISSING',
#    'Unidentified Gang (Mexico)',
#    'MISSING'),
#   49930),
#  (104,
#   ('QSD: Syrian Democratic Forces', 'MISSING', 'MISSING', 'MISSING'),
#   38663),
#  (104,
#   ('Protesters (United States)',
#    'Jewish Group (United States)',
#    'MISSING',
#    'MISSING'),
#   36989),
#  (104,
#   ('Protesters (Tunisia)', 'Labor Group (Tunisia)', 'MISSING', 'MISSING'),
#   33907),
#  (104,
#   ('Protesters (Spain)', 'Students (Spain)', 'MISSING', 'MISSING'),
#   33178),
#  (104,
#   ('Protesters (South Korea)',
#    'KFEM: Korea Federation for Environmental Movement',
#    'MISSING',
#    'MISSING'),
#   32397),
#  (104,
#   ('Protesters (Germany)',
#    'FFF: Fridays for Future; Students (Germany)',
#    'MISSING',
#    'MISSING'),
#   21763),
#  (104,
#   ('Protesters (Bulgaria)', 'Labor Group (Bulgaria)', 'MISSING', 'MISSING'),
#   18470),
#  (104,
#   ('Protesters (Bolivia)',
#    'MAS-IPSP: Movement for Socialism-Political Instrument for the Sovereignty of the Peoples',
#    'MISSING',
#    'MISSING'),
#   18214),
#  (104,
#   ('Islamic State Sahel Province (ISSP)',
#    'MISSING',
#    'Civilians (Niger)',
#    'MISSING'),
#   4887),
#  (104, ('Al Shabaab', 'MISSING', 'MISSING', 'MISSING'), 877),
#  (103,
#   ('Protesters (India)',
#    'TMC: Trinamool Congress Party',
#    'MISSING',
#    'MISSING'),
#   25318),
#  (103,
#   ('Protesters (India)',
#    'AJYCP: Asom Jatiyatabadi Yuva Chatra Parishad; Students (India)',
#    'MISSING',
#    'MISSING'),
#   23119),
#  (103,
#   ('Military Forces of Nigeria (2023-)',
#    'MISSING',
#    'Kaduna Communal Militia (Nigeria)',
#    'MISSING'),
#   9482),
#  (102,
#   ('Protesters (Italy)',
#    'Farmers (Italy); RA: Agrarian Redemption',
#    'MISSING',
#    'MISSING'),
#   26829),
#  (102,
#   ('Protesters (Indonesia)', 'Muslim Group (Indonesia)', 'MISSING', 'MISSING'),
#   25697),
#  (101,
#   ('Protesters (South Korea)',
#    'Government of South Korea (2022-)',
#    'MISSING',
#    'MISSING'),
#   32246),
#  (101,
#   ('Protesters (Paraguay)', 'Students (Paraguay)', 'MISSING', 'MISSING'),
#   30810),
#  (101,
#   ('Protesters (India)',
#    'Labor Group (India); Teachers (India)',
#    'MISSING',
#    'MISSING'),
#   24977),
#  (101,
#   ('Protesters (India)',
#    'Health Workers (India); Labor Group (India)',
#    'MISSING',
#    'MISSING'),
#   24530),
#  (101,
#   ('Military Forces of Myanmar (2021-)',
#    'Police Forces of Myanmar (2021-)',
#    'Civilians (Myanmar)',
#    'MISSING'),
#   9248),
#  (100, ('Rioters (Bangladesh)', 'MISSING', 'MISSING', 'MISSING'), 39601),
#  (100,
#   ('Rioters (Bahrain)', 'February 14 Youth Coalition', 'MISSING', 'MISSING'),
#   39186),
#  (100, ('Protesters (France)', 'Women (France)', 'MISSING', 'MISSING'), 21240),
#  (100,
#   ('KIO/KIA: Kachin Independence Organization/Kachin Independence Army',
#    'MISSING',
#    'Military Forces of Myanmar (2021-)',
#    'MISSING'),
#   5712),
#  (100,
#   ('JNIM: Group for Support of Islam and Muslims',
#    'MISSING',
#    'Military Forces of Burkina Faso (2022-)',
#    'MISSING'),
#   5444),
#  (100,
#   ('Fulani Ethnic Militia (Nigeria)',
#    'Pastoralists (Nigeria)',
#    'Civilians (Nigeria)',
#    'MISSING'),
#   3651),
#  (99,
#   ('Unidentified Gang and/or Police Militia',
#    'MISSING',
#    'Unidentified Gang and/or Police Militia',
#    'MISSING'),
#   50071),
#  (99,
#   ('Protesters (United States)',
#    'PSL: Party for Socialism and Liberation',
#    'MISSING',
#    'MISSING'),
#   37569),
#  (99,
#   ('Protesters (Mexico)', 'Taxi/Bus Drivers (Mexico)', 'MISSING', 'MISSING'),
#   28606),
#  (99,
#   ('Protesters (France)', 'Teachers (France)', 'MISSING', 'MISSING'),
#   21232),
#  (99,
#   ('Protesters (France)',
#    'CFDT: French Democratic Confederation of Labor; CGT: General Confederation of Labor (France); FSU: United Federation of Trade Unions; Labor Group (France); SUD: Democratic Unitary Solidarity; UNSA: National Union of Autonomous Trade Unions',
#    'MISSING',
#    'MISSING'),
#   20378),
#  (98,
#   ('Unidentified Tribal Militia (Iraq)',
#    'MISSING',
#    'Unidentified Tribal Militia (Iraq)',
#    'MISSING'),
#   50146),
#  (98,
#   ('Protesters (United States)',
#    'Teachers (United States)',
#    'MISSING',
#    'MISSING'),
#   37976),
#  (98, ('Protesters (New Zealand)', 'MISSING', 'MISSING', 'MISSING'), 29473),
#  (98,
#   ('Military Forces of Myanmar (2021-)',
#    'MISSING',
#    'Civilians (Myanmar)',
#    'Labor Group (Myanmar)'),
#   8894),
#  (98,
#   ('Military Forces of Israel (2022-)',
#    'MISSING',
#    'Civilians (Palestine)',
#    'Labor Group (Palestine)'),
#   8240),
#  (98,
#   ('CV: Red Command', 'MISSING', 'TCP: Pure Third Command', 'MISSING'),
#   2436),
#  (97,
#   ('Protesters (Taiwan)',
#    'Government of Taiwan (2016-); KMT: Kuomintang',
#    'MISSING',
#    'MISSING'),
#   33674),
#  (96,
#   ('Protesters (India)', 'Government of India (2014-)', 'MISSING', 'MISSING'),
#   24374),
#  (96,
#   ('Protesters (Democratic Republic of Congo)',
#    'MISSING',
#    'MISSING',
#    'MISSING'),
#   19650),
#  (96,
#   ('Military Forces of Brazil (2023-) Military Police',
#    'MISSING',
#    'BDM: Bonde do Maluco',
#    'MISSING'),
#   7384),
#  (95,
#   ('Protesters (Yemen)',
#    'Government of Yemen (2017-) Houthi; Labor Group (Yemen)',
#    'MISSING',
#    'MISSING'),
#   38405),
#  (95,
#   ('Protesters (France)',
#    'CGT: General Confederation of Labor (France); FSU: United Federation of Trade Unions; Labor Group (France); SUD: Democratic Unitary Solidarity',
#    'MISSING',
#    'MISSING'),
#   20574),
#  (94, ('Protesters (Kyrgyzstan)', 'MISSING', 'MISSING', 'MISSING'), 27890),
#  (94,
#   ('Protesters (Italy)',
#    'CGIL: Italian General Confederation of Labor; CISL: Italian Confederation of Trade Unions; Labor Group (Italy); UIL: Italian Labor Union',
#    'MISSING',
#    'MISSING'),
#   26573),
#  (94,
#   ('Military Forces of Russia (2000-)',
#    'MISSING',
# ...
#    'MISSING'),
#   49963),
#  (41,
#   ('Unidentified Gang (Haiti)',
#    'MISSING',
#    'Police Forces of Haiti (2017-2024)',
#    'MISSING'),
#   49723),
#  (41,
#   ('Unidentified Armed Group (Nigeria)',
#    'MISSING',
#    'Police Forces of Nigeria (2023-)',
#    'MISSING'),
#   48411),
#  (41,
#   ('Rioters (India)', 'MISSING', 'Civilians (India)', 'Labor Group (India)'),
#   41693),
#  (41,
#   ('Rioters (India)', 'BJP: Bharatiya Janata Party', 'MISSING', 'MISSING'),
#   41027),
#  (41,
#   ('Rioters (Bangladesh)',
#    'AL: Bangladesh Awami League',
#    'Civilians (Bangladesh)',
#    'Independent Politicians (Bangladesh)'),
#   39213),
#  (41,
#   ('Protesters (United States)',
#    "AFL-CIO: American Federation of Labor and Congress of Industrial Organizations; ILA: International Longshoreman's Association; Labor Group (United States)",
#    'MISSING',
#    'MISSING'),
#   35461),
#  (41,
#   ('Protesters (Spain)',
#    'CCOO: Workers Commissions; Labor Group (Spain)',
#    'MISSING',
#    'MISSING'),
#   32816),
#  (41, ('Protesters (Senegal)', 'MISSING', 'MISSING', 'MISSING'), 31551),
#  (41,
#   ('Protesters (Pakistan)', 'Hindu Group (Pakistan)', 'MISSING', 'MISSING'),
#   30143),
#  (41, ('Protesters (Kenya)', 'Farmers (Kenya)', 'MISSING', 'MISSING'), 27712),
#  (41,
#   ('Protesters (Indonesia)',
#    'HMI: Muslim Students Association; Muslim Group (Indonesia); Students (Indonesia)',
#    'MISSING',
#    'MISSING'),
#   25592),
#  (41,
#   ('Protesters (India)',
#    'INDIA: Indian National Developmental Inclusive Alliance; INC: Indian National Congress; RLD: Rashtriya Lok Dal; SP: Samajwadi Party; CPI(M): Communist Party of India (Marxist)',
#    'MISSING',
#    'MISSING'),
#   24702),
#  (41,
#   ('Protesters (Honduras)', 'Teachers (Honduras)', 'MISSING', 'MISSING'),
#   22546),
#  (41,
#   ('Protesters (Germany)',
#    'MISSING',
#    'Police Forces of Germany (2021-)',
#    'MISSING'),
#   22020),
#  (41,
#   ('Police Forces of India (2014-)',
#    'MISSING',
#    'Civilians (India)',
#    'Prisoners (India)'),
#   14447),
#  (41,
#   ('Military Forces of Russia (2000-)',
#    'MISSING',
#    'Military Forces of Ukraine (2019-)',
#    'Military Forces of Ukraine (2019-) Territorial Defense Forces'),
#   9671),
#  (41,
#   ('Military Forces of Myanmar (2021-)',
#    'MISSING',
#    'MNTJP/MNDAA: Myanmar National Truth and Justice Party/Myanmar National Democratic Alliance Army',
#    'MISSING'),
#   9032),
#  (41,
#   ('Military Forces of Iraq (2022-)', 'MISSING', 'MISSING', 'MISSING'),
#   8004),
#  (41,
#   ('Military Forces of Burkina Faso (2022-)',
#    'VDP: Volunteer for Defense of Homeland',
#    'JNIM: Group for Support of Islam and Muslims',
#    'MISSING'),
#   7470),
#  (41,
#   ('Military Forces of Brazil (2023-) Military Police',
#    'MISSING',
#    'TCP: Pure Third Command',
#    'MISSING'),
#   7411),
#  (41,
#   ('HTS: Hayat Tahrir al Sham', 'MISSING', 'Civilians (Syria)', 'MISSING'),
#   4413),
#  (41,
#   ('Global Coalition Against Daesh',
#    'MISSING',
#    'Militia (Pro-Iran)',
#    'MISSING'),
#   3801),
#  (41,
#   ('CODECO: Cooperative for Development of Congo',
#    'MISSING',
#    'Civilians (Democratic Republic of Congo)',
#    'MISSING'),
#   2314),
#  (40, ('Wagner Group', 'MISSING', 'Civilians (Mali)', 'MISSING'), 50296),
#  (40,
#   ('Rioters (Democratic Republic of Congo)',
#    'Vigilante Group (Democratic Republic of Congo)',
#    'Civilians (Democratic Republic of Congo)',
#    'MISSING'),
#   40339),
#  (40,
#   ('Protesters (Spain)',
#    'CIG: Galician Inter-Union Confederation; Labor Group (Spain)',
#    'MISSING',
#    'MISSING'),
#   32859),
#  (40, ('Protesters (Portugal)', 'Home to Live', 'MISSING', 'MISSING'), 31289),
#  (40,
#   ('Protesters (Nigeria)',
#    'MISSING',
#    'Police Forces of Nigeria (2023-)',
#    'MISSING'),
#   29632),
#  (40,
#   ('Protesters (India)', 'RJD: Rashtriya Janata Dal', 'MISSING', 'MISSING'),
#   25170),
#  (40,
#   ('Protesters (India)',
#    'MP: Women Torch Bearers; Women (India); Meitei Ethnic Group (India)',
#    'MISSING',
#    'MISSING'),
#   25023),
#  (40,
#   ('Protesters (India)',
#    'Health Workers (India); IMA: Indian Medical Association; Students (India)',
#    'MISSING',
#    'MISSING'),
#   24520),
#  (40,
#   ('Protesters (India)',
#    'Former Government of India (2014-)',
#    'MISSING',
#    'MISSING'),
#   24240),
#  (40,
#   ('Protesters (India)',
#    'AAP: Aam Aadmi Party; Government of India (2014-)',
#    'MISSING',
#    'MISSING'),
#   22692),
#  (40,
#   ('Protesters (Canada)', 'Labor Group (Canada)', 'MISSING', 'MISSING'),
#   18798),
#  (40,
#   ('Protesters (Bolivia)',
#    'MAS-IPSP: Movement for Socialism-Political Instrument for the Sovereignty of the Peoples; Farmers (Bolivia)',
#    'MISSING',
#    'MISSING'),
#   18216),
#  (40,
#   ('Protesters (Bangladesh)',
#    'AL: Bangladesh Awami League',
#    'MISSING',
#    'MISSING'),
#   17632),
#  (40,
#   ('Police Forces of Syria (2000-)',
#    'MISSING',
#    'Civilians (Syria)',
#    'MISSING'),
#   15978),
#  (40,
#   ('Police Forces of Kenya (2022-)',
#    'MISSING',
#    'Civilians (Kenya)',
#    'MISSING'),
#   15032),
#  (40,
#   ('Military Forces of Russia (2000-)',
#    'Military Forces of Russia (2000-) Air Force',
#    'Military Forces of Ukraine (2019-)',
#    'Military Forces of Ukraine (2019-) Air Force'),
#   9710),
#  (40,
#   ('Military Forces of Ethiopia (2018-)',
#    'MISSING',
#    'Civilians (Ethiopia)',
#    'OLF-OLA: Oromo Liberation Army-Oromo Liberation Front'),
#   7749),
#  (40,
#   ('Ambazonian Separatists (Cameroon)',
#    'MISSING',
#    'Civilians (Cameroon)',
#    'Women (Cameroon)'),
#   1212),
#  (39,
#   ('Unidentified Cult Militia (Nigeria)',
#    'MISSING',
#    'Unidentified Cult Militia (Nigeria)',
#    'MISSING'),
#   49558),
#  (39,
#   ('Unidentified Armed Group (Mexico)',
#    'MISSING',
#    'Police Forces of Mexico (2018-) Ministerial Federal Police',
#    'MISSING'),
#   48088),
#  (39,
#   ('Rioters (Bangladesh)',
#    'Labor Group (Bangladesh); Students (Bangladesh)',
#    'Police Forces of Bangladesh (2009-2024)',
#    'MISSING'),
#   39534),
#  (39,
#   ('Rapid Support Forces', 'MISSING', 'Civilians (Sudan)', 'Farmers (Sudan)'),
#   38864),
#  (39,
#   ('QSD: Syrian Democratic Forces',
#    'MISSING',
#    'Military Forces of Syria (2000-)',
#    'MISSING'),
#   38667),
#  (39,
#   ('Protesters (Turkey)', 'Teachers (Turkey)', 'MISSING', 'MISSING'),
#   34963),
#  (39,
#   ('Protesters (Turkey)', 'Lawyers (Turkey)', 'MISSING', 'MISSING'),
#   34848),
#  (39, ('Protesters (Syria)', 'Women (Syria)', 'MISSING', 'MISSING'), 33588),
#  (39, ('Protesters (Mali)', 'MISSING', 'MISSING', 'MISSING'), 28165),
#  (39,
#   ('Protesters (Germany)',
#    'Last Generation (Germany)',
#    'Police Forces of Germany (2021-)',
#    'MISSING'),
#   22001),
#  (39,
#   ('Police Forces of Iraq (2022-)',
#    'MISSING',
#    'Unidentified Armed Group (Iraq)',
#    'MISSING'),
#   14851),
#  (39,
#   ('Police Forces of India (2014-)',
#    'MISSING',
#    'Civilians (India)',
#    'MISSING'),
#   14439),
#  (39,
#   ('Police Forces of China (2012-)',
#    'MISSING',
#    'Civilians (China)',
#    'Women (China)'),
#   13970),
#  (39,
#   ('M23: March 23 Movement',
#    'Military Forces of Rwanda (1994-)',
#    'Military Forces of the Democratic Republic of Congo (2019-)',
#    'EPLC: Awakening of Patriots for the Liberation of Congo (Wazalendo)'),
#   6710),
#  (39, ('GDL: Goyim Defense League', 'MISSING', 'MISSING', 'MISSING'), 3696),
#  (39,
#   ('Fulani Ethnic Militia (Nigeria)',
#    'Pastoralists (Nigeria)',
#    'Civilians (Nigeria)',
#    'Farmers (Nigeria)'),
#   3634),
#  (38,
#   ('TPNPB: West Papua National Liberation Army',
#    'MISSING',
#    'Military Forces of Indonesia (2014-2024)',
#    'MISSING'),
#   45576),
#  (38, ('Rioters (Syria)', 'MISSING', 'MISSING', 'MISSING'), 44493),
#  (38,
#   ('Protesters (United States)',
#    'WLM: White Lives Matter',
#    'MISSING',
#    'MISSING'),
#   38031),
#  (38,
#   ('Protesters (United States)',
#    'Jewish Group (United States); Students (United States)',
#    'MISSING',
#    'MISSING'),
#   37130),
#  (38,
#   ('Protesters (United States)',
#    'Government of the United States (2021-)',
#    'MISSING',
#    'MISSING'),
#   36713),
#  (38,
#   ('Protesters (Poland)',
#    'Catholic Christian Group (Poland)',
#    'MISSING',
#    'MISSING'),
#   31108),
#  (38, ('Protesters (Peru)', 'Farmers (Peru)', 'MISSING', 'MISSING'), 30849),
#  (38,
#   ('Protesters (Kenya)',
#    'MISSING',
#    'Police Forces of Kenya (2022-)',
#    'MISSING'),
#   27814),
#  (38,
#   ('Protesters (Indonesia)',
#    'BEM SI: Indonesian Students Executive Board; Students (Indonesia)',
#    'MISSING',
#    'MISSING'),
#   25458),
#  (38,
#   ('Protesters (India)',
#    'Bajrang Dal; Hindu Group (India); VHP: Vishwa Hindu Parishad',
#    'MISSING',
#    'MISSING'),
#   23615),
#  (38,
#   ('Protesters (India)',
#    'BRS: Bharat Rashtra Samithi; Former Government of India (2014-); Government of India (2014-)',
#    'MISSING',
#    'MISSING'),
#   23550),
#  (38,
#   ('Protesters (Germany)', 'MISSING', 'Protesters (Germany)', 'MISSING'),
#   22031),
#  (38,
#   ('Protesters (Australia)', 'Students (Australia)', 'MISSING', 'MISSING'),
#   17460),
#  (38,
#   ('Police Forces of Turkey (2016-)',
#    'MISSING',
#    'Civilians (International)',
#    'Refugees/IDPs (International)'),
#   16052),
#  (38,
#   ('Police Forces of Malaysia (2022-)',
#    'MISSING',
#    'Civilians (International)',
#    'Labor Group (International)'),
#   15160),
#  (38,
#   ('Military Forces of Turkey (2016-)',
#    'MISSING',
#    'Civilians (Syria)',
#    'MISSING'),
#   10494),
#  (38,
#   ('Military Forces of Colombia (2022-)',
#    'MISSING',
#    'ELN: National Liberation Army',
#    'MISSING'),
#   7621),
#  (38,
#   ("Lions' Den", 'MISSING', 'Military Forces of Israel (2022-)', 'MISSING'),
#   6492),
#  (38,
#   ('Kuki Tribal Militia (India)',
#    'MISSING',
#    'Civilians (India)',
#    'Meitei Ethnic Group (India)'),
#   6320),
#  (38,
#   ('JNIM: Group for Support of Islam and Muslims',
#    'MISSING',
#    'Civilians (Benin)',
#    'MISSING'),
#   5343),
#  (38,
#   ('Islamic State West Africa Province (ISWAP) and/or Boko Haram - Jamaatu Ahli is-Sunnah lid-Dawati wal-Jihad',
#    'MISSING',
#    'Civilians (Cameroon)',
#    'Pastoralists (Cameroon)'),
#   5036),
#  (38,
#   ('Baloch Separatists (Pakistan)',
#    'MISSING',
#    'Military Forces of Pakistan (2022-)',
#    'MISSING'),
#   1780),
#  (37,
#   ('Unidentified Armed Group (Italy)',
#    'MISSING',
#    'Civilians (Italy)',
#    'Government of Italy (2022-)'),
#   47664),
#  (37, ('Rioters (Mexico)', 'MISSING', 'MISSING', 'MISSING'), 43083),
#  (37,
#   ('Rioters (Germany)',
#    'MISSING',
#    'Police Forces of Germany (2021-)',
#    'MISSING'),
#   40581),
#  (37,
#   ('Protesters (Yemen)', 'Labor Group (Yemen)', 'MISSING', 'MISSING'),
#   38456),
#  (37,
#   ('Protesters (Venezuela)',
#    'Labor Group (Venezuela); Teachers (Venezuela)',
#    'MISSING',
#    'MISSING'),
#   38233),
#  (37,
#   ('Protesters (United States)',
#    'Jewish Group (United States); JVP: Jewish Voice for Peace',
#    'MISSING',
#    'MISSING'),
#   37015),
#  (37,
#   ('Protesters (United States)',
#    'AFSCME: American Federation of State, County and Municipal Employees; Labor Group (United States)',
#    'MISSING',
#    'MISSING'),
#   35500),
#  (37,
#   ('Protesters (South Africa)', 'MK: uMkhonto weSizwe', 'MISSING', 'MISSING'),
#   31951),
#  (37,
#   ('Protesters (Norway)', 'KK: Struggle Committee', 'MISSING', 'MISSING'),
#   29777),
#  (37, ('Protesters (Nepal)', 'Farmers (Nepal)', 'MISSING', 'MISSING'), 29123),
#  (37,
#   ('Protesters (Mexico)',
#    'MORENA: National Regeneration Movement',
#    'MISSING',
#    'MISSING'),
#   28536),
#  (37,
#   ('Protesters (Indonesia)', 'Teachers (Indonesia)', 'MISSING', 'MISSING'),
#   25795),
#  (37,
#   ('Protesters (India)',
#    'INDIA: Indian National Developmental Inclusive Alliance',
#    'MISSING',
#    'MISSING'),
#   24696),
#  (37,
#   ('Protesters (India)',
#    'Farmers (India)',
#    'Police Forces of India (2014-)',
#    'MISSING'),
#   24090),
#  (37,
#   ('Protesters (India)',
#    'BJP: Bharatiya Janata Party; Former Government of India (2014-)',
#    'MISSING',
#    'MISSING'),
#   23328),
#  (37,
#   ('Protesters (Greece)', 'Students (Greece)', 'MISSING', 'MISSING'),
#   22340),
#  (37,
#   ('Protesters (Greece)', 'Labor Group (Greece)', 'MISSING', 'MISSING'),
#   22296),
#  (37,
#   ('Protesters (Germany)',
#    'Grannies Against the Right (Germany); Women (Germany)',
#    'MISSING',
#    'MISSING'),
#   21900),
#  (37,
#   ('Protesters (Germany)',
#    'Christian Group (Germany); Labor Group (Germany); NGPM: Network of the German Peace Movement',
#    'MISSING',
#    'MISSING'),
#   21662),
#  (37,
#   ('Protesters (France)',
#    'CFDT: French Democratic Confederation of Labor; Labor Group (France)',
#    'MISSING',
#    'MISSING'),
#   20410),
#  (37,
#   ('Protesters (Canada)', 'Ukrainian Group (Canada)', 'MISSING', 'MISSING'),
#   18929),
#  (37,
#   ('Protesters (Bangladesh)',
#    'BNP: Bangladesh Nationalist Party; JeI: Jamaat-e-Islami',
#    'MISSING',
#    'MISSING'),
#   17722),
#  (37,
#   ('Protesters (Australia)',
#    'Health Workers (Australia)',
#    'MISSING',
#    'MISSING'),
#   17317),
#  (37,
#   ('Protesters (Argentina)',
#    'Students (Argentina); Teachers (Argentina)',
#    'MISSING',
#    'MISSING'),
#   17071),
#  (37,
#   ('Operation Restoring Hope',
#    'Military Forces of Saudi Arabia (2015-)',
#    'MISSING',
#    'MISSING'),
#   12104),
#  (37,
#   ('Military Forces of Somalia (2022-)',
#    'MISSING',
#    'Military Forces of Somalia (2022-)',
#    'MISSING'),
#   9926),
#  (37,
#   ('Military Forces of Russia (2000-) Air Force',
#    'Military Forces of Russia (2000-)',
#    'Military Forces of Ukraine (2019-)',
#    'Military Forces of Ukraine (2019-) Marines; Military Forces of Ukraine (2019-) National Guard; Military Forces of Ukraine (2019-) Special Forces; Military Forces of Ukraine (2019-) Territorial Defense Forces'),
#   9807),
#  (37,
#   ('Military Forces of Myanmar (2021-)',
#    'MISSING',
#    'PNLO/PNLA: Pa-Oh National Liberation Organization/Pa-Oh National Liberation Army',
#    'MISSING'),
#   9068),
#  (37,
#   ('Military Forces of Mexico (2018-)', 'MISSING', 'MISSING', 'MISSING'),
#   8704),
#  (37,
#   ('Military Forces of Lebanon (2021-)',
#    'MISSING',
#    'Military Forces of Israel (2022-)',
#    'MISSING'),
#   8531),
#  (37,
#   ('Military Forces of Israel (2022-)',
#    'MISSING',
#    'Military Forces of Syria (2000-)',
#    'MISSING'),
#   8387),
#  (37,
#   ('Military Forces of Israel (2022-)',
#    'MISSING',
#    'Islamic Resistance in Iraq',
#    'MISSING'),
#   8354),
#  (37,
#   ('Military Forces of Cameroon (1982-) Rapid Intervention Battalion',
#    'MISSING',
#    'Ambazonian Separatists (Cameroon)',
#    'MISSING'),
#   7568),
#  (37,
#   ('Islamic State in Iraq and the Levant (ISIL)',
#    'MISSING',
#    'Civilians (Syria)',
#    'MISSING'),
#   5164),
#  (37,
#   ('Dahalo Militia',
#    'MISSING',
#    'Military Forces of Madagascar (2019-) Gendarmerie',
#    'MISSING'),
#   2866),
#  (37,
#   ('Al Shabaab', 'MISSING', 'Police Forces of Kenya (2022-)', 'MISSING'),
#   929),
#  (37,
#   ('ADF: Allied Democratic Forces',
#    'MISSING',
#    'Civilians (Democratic Republic of Congo)',
#    'Farmers (Democratic Republic of Congo)'),
#   278),
#  (36,
#   ('Unidentified Armed Group (Mexico)',
#    'MISSING',
#    'Military Forces of Mexico (2018-)',
#    'MISSING'),
#   48070),
#  (36,
#   ('Unidentified Armed Group (India)',
#    'MISSING',
#    'Civilians (India)',
#    'Labor Group (India)'),
#   47395),
#  (36,
#   ('Unidentified Armed Group (France)',
#    'MISSING',
#    'Civilians (France)',
#    'MISSING'),
#   47016),
#  (36,
#   ('Rioters (Nigeria)',
#    'MISSING',
#    'Police Forces of Nigeria (2023-)',
#    'MISSING'),
#   43512),
#  (36,
#   ('Rioters (Martinique)',
#    'MISSING',
#    'Military Forces of France (2017-) Gendarmerie Martinique',
#    'MISSING'),
#   42947),
#  (36,
#   ('Protesters (United Kingdom)',
#    'XR: Extinction Rebellion',
#    'MISSING',
#    'MISSING'),
#   35268),
#  (36,
#   ('Protesters (Panama)',
#    'Labor Group (Panama); SUNTRACS: Single Union of Construction and Associated Workers',
#    'MISSING',
#    'MISSING'),
#   30656),
#  (36,
#   ('Protesters (Palestine)', 'Students (Palestine)', 'MISSING', 'MISSING'),
#   30618),
#  (36,
#   ('Protesters (Pakistan)',
#    'STPP: Sindh Taraqi Pasand Party',
#    'MISSING',
#    'MISSING'),
#   30452),
#  (36,
#   ('Protesters (Nigeria)', 'Students (Nigeria)', 'MISSING', 'MISSING'),
#   29682),
#  (36,
#   ('Protesters (Morocco)', 'Health Workers (Morocco)', 'MISSING', 'MISSING'),
#   28813),
#  (36,
#   ('Protesters (Mexico)',
#    'Judges (Mexico); Labor Group (Mexico); Students (Mexico)',
#    'MISSING',
#    'MISSING'),
#   28470),
#  (36, ('Protesters (Lithuania)', 'MISSING', 'MISSING', 'MISSING'), 28034),
#  ...]

# %%
def get_story(i):
    temp = sorted_stories[i][1]
    # print(temp)
    return df.iloc[duplicate_groups[temp].tolist()]

# %%
get_story(1)
# Out:
#        event_id_cnty        event_date  year  time_precision  \
# 132         LBN28153   31 October 2024  2024               1
# 134         LBN28155   31 October 2024  2024               1
# 135         LBN28156   31 October 2024  2024               1
# 136         LBN28157   31 October 2024  2024               1
# 137         LBN28158   31 October 2024  2024               1
# ...              ...               ...   ...             ...
# 372484      LBN15692  01 November 2023  2023               1
# 372485      LBN15805  01 November 2023  2023               1
# 372486      LBN15806  01 November 2023  2023               1
# 372487      LBN15807  01 November 2023  2023               1
# 372488      LBN20791  01 November 2023  2023               1
#
#              disorder_type                  event_type  \
# 132     Political violence  Explosions/Remote violence
# 134     Political violence  Explosions/Remote violence
# 135     Political violence  Explosions/Remote violence
# 136     Political violence  Explosions/Remote violence
# 137     Political violence  Explosions/Remote violence
# ...                    ...                         ...
# 372484  Political violence  Explosions/Remote violence
# 372485  Political violence  Explosions/Remote violence
# 372486  Political violence  Explosions/Remote violence
# 372487  Political violence  Explosions/Remote violence
# 372488  Political violence  Explosions/Remote violence
#
#                            sub_event_type                             actor1  \
# 132                      Air/drone strike  Military Forces of Israel (2022-)
# 134                      Air/drone strike  Military Forces of Israel (2022-)
# 135     Shelling/artillery/missile attack  Military Forces of Israel (2022-)
# 136     Shelling/artillery/missile attack  Military Forces of Israel (2022-)
# 137                      Air/drone strike  Military Forces of Israel (2022-)
# ...                                   ...                                ...
# 372484                   Air/drone strike  Military Forces of Israel (2022-)
# 372485  Shelling/artillery/missile attack  Military Forces of Israel (2022-)
# 372486  Shelling/artillery/missile attack  Military Forces of Israel (2022-)
# 372487  Shelling/artillery/missile attack  Military Forces of Israel (2022-)
# 372488  Shelling/artillery/missile attack  Military Forces of Israel (2022-)
#
#        assoc_actor_1                 inter1  ... latitude longitude  \
# 132              NaN  External/Other forces  ...  33.4869   35.5188
# 134              NaN  External/Other forces  ...  33.3642   35.4322
# 135              NaN  External/Other forces  ...  33.3347   35.5709
# 136              NaN  External/Other forces  ...  33.3215   35.5632
# 137              NaN  External/Other forces  ...  33.3477   35.4183
# ...              ...                    ...  ...      ...       ...
# 372484           NaN  External/Other forces  ...  33.1108   35.3103
# 372485           NaN  External/Other forces  ...  33.1400   35.5147
# 372486           NaN  External/Other forces  ...  33.1108   35.3103
# 372487           NaN  External/Other forces  ...  33.1064   35.2324
# 372488           NaN  External/Other forces  ...  33.1265   35.2560
#
#        geo_precision                                  source  \
# 132                1  National News Agency Lebanon; Telegram
# 134                1  National News Agency Lebanon; Telegram
# 135                2            National News Agency Lebanon
# 136                2  National News Agency Lebanon; Telegram
# 137                2            National News Agency Lebanon
# ...              ...                                     ...
# 372484             1                               El Nashra
# 372485             1                                An-Nahar
# 372486             1                     AlManar TV; Twitter
# 372487             2            National News Agency Lebanon
# 372488             1                                 Twitter
#
#               source_scale                                              notes  \
# 132     New media-National  On 31 October 2024, Israeli warplanes carried ...
# 134     New media-National  On 31 October 2024, Israeli warplanes carried ...
# 135               National  On 31 October 2024, the Israeli military fired...
# 136     New media-National  On 31 October 2024, the Israeli military fired...
# 137               National  On 31 October 2024, Israeli warplanes carried ...
# ...                    ...                                                ...
# 372484            National  On 1 November 2023, Israeli fighter jets struc...
# 372485            National  On 1 November 2023, Israeli military forces sh...
# 372486  New media-National  On 1 November 2023, Israeli military forces sh...
# 372487            National  On 1 November 2023, Israeli military forces sh...
# 372488           New media  On 1 November 2023, Israeli military forces sh...
#
#        fatalities tags   timestamp population_best
# 132             0  NaN  1730764851          3200.0
# 134             0  NaN  1730764851         10893.0
# 135             0  NaN  1730764851          5663.0
# 136             0  NaN  1730764851          1007.0
# 137             0  NaN  1730764851          3915.0
# ...           ...  ...         ...             ...
# 372484          0  NaN  1727907797          1394.0
# 372485          0  NaN  1727907797          1634.0
# 372486          0  NaN  1727907797          1394.0
# 372487          0  NaN  1727907797          1847.0
# 372488          0  NaN  1727907799           760.0
#
# [14296 rows x 32 columns]

# %%
test_sequence = embed_story(get_story(0))
test_sequence.shape
# Out:
# torch.Size([366, 3])

# %%
import math

def create_sinusoidal_positional_encoding(max_seq_len, d_model):
    position = torch.arange(0, max_seq_len, dtype=torch.float).unsqueeze(1)  # [max_seq_len, 1]
    div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model))  # [d_model // 2]

    positional_encoding = torch.zeros(max_seq_len, d_model)
    positional_encoding[:, 0::2] = torch.sin(position * div_term)  # Even indices
    positional_encoding[:, 1::2] = torch.cos(position * div_term)  # Odd indices

    return positional_encoding

# %%
class DayLevelTransformerModel(nn.Module):
    def __init__(self, d_model, num_heads=3, num_layers=6, max_seq_len=512):
        super(DayLevelTransformerModel, self).__init__()
        
        self.in_dim = 3
        self.d_model = d_model
        self.max_seq_len = max_seq_len
        

        self.positional_encoding = create_sinusoidal_positional_encoding(max_seq_len, self.d_model)

        self.fc_in = nn.Linear(self.in_dim, self.d_model)

 
        self.transformer_encoder_layer = nn.TransformerEncoderLayer(d_model=self.d_model, nhead=num_heads)
        self.transformer_encoder = nn.TransformerEncoder(self.transformer_encoder_layer, num_layers=num_layers)
        self.transformer_decoder_layer = nn.TransformerDecoderLayer(d_model=self.d_model, nhead=num_heads)
        self.transformer_decoder = nn.TransformerDecoder(self.transformer_decoder_layer, num_layers=num_layers)


        self.fc_out = nn.Linear(self.d_model, self.in_dim) 

    def forward(self, x, y):

        x = self.fc_in(x) + self.positional_encoding
        y = self.fc_in(y) + self.positional_encoding
        
        memory = self.transformer_encoder(x) 
        output = self.transformer_decoder(y, memory)
        

        final = self.fc_out(output)
        return final

    def generate(self, x, max_length=20):
      
        generated = x 
        
        for _ in range(max_length):
            output = self.forward(generated, generated)  
            next_token = output[-1, :, :].argmax(dim=-1)  
            
            generated = torch.cat((generated, next_token.unsqueeze(0)), dim=0)  
            
        return generated

# %%
sequences = [
    embed_story(get_story(i)).float() for i in tqdm.tqdm(range(1000))
]
# Out:
# 100%|██████████| 1000/1000 [00:55<00:00, 18.16it/s]

# %%
train_sequences = []

for i in tqdm.tqdm(range(1000)):
    story = get_story(i)
    temp = story[pd.to_datetime(story['event_date'], format='%d %B %Y') < pd.to_datetime('01 October 2024', format='%d %B %Y')]
    if len(temp) > 0:
        train_sequences.append(embed_story(temp))
# Out:
# 100%|██████████| 1000/1000 [00:44<00:00, 22.51it/s]

# %%
train_sequences[9].sum(axis=0)
# Out:
# tensor([1.8457e+02, 3.3500e+02, 3.0000e-02])

# %%
seq_len = 10 
batch_size = 4

max_len = max(seq.size(0) for seq in sequences)
model = DayLevelTransformerModel(12, max_seq_len=max_len-1)

padded_sequences = []
for seq in sequences:
    padded_seq = F.pad(seq, (0, 0, 0, max_len - seq.size(0))) 
    padded_sequences.append(padded_seq)

stacked = torch.stack(padded_sequences)

batches = [ stacked[i*batch_size:(i+1)*batch_size] for i in range(len(stacked) // batch_size) ]


criterion = nn.MSELoss()  
optimizer = optim.Adam(model.parameters())

model.train()
for epoch in range(10): 
    losses = []
    for batch in tqdm.tqdm(batches):
        optimizer.zero_grad()
        
        input_sequence = batch[:, :-1]
        target_sequence = batch[:, 1:]

        logits = model(input_sequence, target_sequence)
        
        loss = criterion(logits, target_sequence)
        losses.append(loss.item())
        
        loss.backward()
        optimizer.step()
        
    print(f"Epoch {epoch+1}, Loss: {sum(losses)/len(losses)}")
# Out:
#  10%|█         | 25/250 [00:14<02:06,  1.78it/s]
